# %%
import string
import sys
import os
import pandas as pd
import numpy as np

# %%
Dictionary1= pd.read_csv("/Users/kamakshibansal/dictionary.csv")
File1= pd.read_csv("/Users/kamakshibansal/Downloads/File1.csv")
File2= pd.read_csv("/Users/kamakshibansal/Downloads/File2.csv")
File3= pd.read_csv("/Users/kamakshibansal/Downloads/File3.csv")

# %%
Dictionary1.feedback = Dictionary1.feedback.replace('\s+', ' ', regex=True)
File1.feedback = File1.feedback.replace('\s+', ' ', regex=True)
File2.feedback = File2.feedback.replace('\s+', ' ', regex=True)
File3.feedback = File3.feedback.replace('\s+', ' ', regex=True)

# %%
Filedict = pd.DataFrame()
Filedict["feedback"]= Dictionary1["feedback"]
Filedict["sentiment"]= Dictionary1["sentiment"]
Filedict["category"]= Dictionary1["category"]
Filedict["Sub_category"]= Dictionary1["subcategory"]

# %%
File11 = pd.DataFrame()
File11["feedback"]= File1["feedback"]
File11["sentiment"]= File1["sentiment"]
File11["category"]= File1["Category"]
File11["Sub_category"]= File1["Sub-category"]

# %%
File22 = pd.DataFrame()
File22["feedback"]= File2["feedback"]
File22["sentiment"]= File2["Sentiment"]
File22["category"]= File2["Category"]
File22["Sub_category"]= File2["Sub-Category"]

# %%
File33 = pd.DataFrame()
File33["feedback"]= File3["feedback"]
File33["sentiment"]= File3["sentiment"]
File33["category"]= File3["Category"]
File33["Sub_category"]= File3["Sub-Category"]

# %%
# Dictionary1.to_csv("A.csv")
# File1.to_csv("A1.csv")
# File2.to_csv("A2.csv")
# File3.to_csv("A3.csv")

# Filedict= pd.read_csv("/Users/kamakshibansal/A.csv")
# File11= pd.read_csv("/Users/kamakshibansal/A1.csv")
# File22= pd.read_csv("/Users/kamakshibansal/A2.csv")
# File33= pd.read_csv("/Users/kamakshibansal/A3.csv")

# %%
Dictionary_new=pd.concat([Filedict, File11,File22, File33])
Dictionary_new.to_csv("A5.csv")

# %%
Dictionary1.head(2)
# Out:
#    category                                           feedback sentiment  \
# 0  Category  I got my order vey fast,the day after i placed...  Positive
# 1   General                                  XXX is amazing...  Positive
#
#       sub-category SurveyName
# 0  Product quality          C
# 1              NaN          C

# %%
import1= pd.read_csv("/Users/kamakshibansal/Downloads/import.csv")
import2= pd.read_csv("/Users/kamakshibansal/Downloads/import3.csv")
import3= pd.read_csv("/Users/kamakshibansal/Downloads/import4.csv")
import4= pd.read_csv("/Users/kamakshibansal/Downloads/import5.csv")

# %%
import1.feedback = import1.feedback.replace('\s+', ' ', regex=True)
import2.feedback = import2.feedback.replace('\s+', ' ', regex=True)
import3.feedback = import3.feedback.replace('\s+', ' ', regex=True)
import4.feedback = import4.feedback.replace('\s+', ' ', regex=True)

# %%
import1.to_csv("B1.csv")
import2.to_csv("B2.csv")
import3.to_csv("B3.csv")
import4.to_csv("B4.csv")

Filedict1= pd.read_csv("/Users/kamakshibansal/B1.csv")
File111= pd.read_csv("/Users/kamakshibansal/B2.csv")
File221= pd.read_csv("/Users/kamakshibansal/B3.csv")
File331= pd.read_csv("/Users/kamakshibansal/B4.csv")

# %%
Dictionary_new1=pd.concat([Filedict1, File111,File221, File331])
Dictionary_new1.to_csv("B.csv")

# %%
Feedback = []
with open("A5.csv", "r") as f:
    r = pd.read_csv(f)
    Feedbacks = list(r["feedback"])

# %%
Feedbacks
# Out:
# ['I got my order vey fast,the day after i placed the order.. this impressed me sooo much..and im very much sartisfied with the product,quality is so good and genuine.. thank you XXX and team.. :)',
#  ' XXX is amazing...',
#  'The delivery was on time.',
#  'I m really happy with this early delivery and quality of product....thank u XXX :)',
#  'Early morning... Ordered at night and next day early morning delivery awesome. Happy',
#  'Excutive was very courteous and gave out all the necessary information regarding the product at the time of delivery.',
#  'Polite and On time delivery. Kudos',
#  'He was patient and did not create fuss when asked to wait ??',
#  'Order is not delivered and I am getting messages that they are delivered. What the hell. And now order is complete',
#  'Early Arrival, Great service delivery',
#  'he was polite enough',
#  'On time delivery, good shipping partner',
#  'The executive is tooo gud. Very well behaved',
#  'excellent service by the delivery person',
#  "Happy with Yogesh's timely delivery.",
#  'The delivery was day before the given day .product is good.love it.??',
#  'The delivery guy reached the exact location and was very humble while communicating to me, such type of people definitely add the value addition to the company.??????????',
#  'Delivered in time. Happy with the service',
#  'Happy with the punctuality of the delivery executive.',
#  'The item is defective',
#  'Delivery executive is very punctual and helpfull',
#  'Abdul rehman its a good delievery thank you',
#  'Please ask ur delivery executive to give a call before coming.',
#  'Nice service..the product as same as in the catalog..i m happy with XXX #happycustomer',
#  "Good service. Love the product in first touch. Let's see after some use.",
#  'Very good service & product also damn good.',
#  'Quick delivery and good delivery person',
#  'Very fast delivery with graceful attitude',
#  'Not delivered, though shows completed',
#  'It is very best site for online shopping',
#  'Very professional delivery person.good behavior',
#  'Very good and professional delivery person ever.',
#  'I have ordered three Items at a time, but received only two items, this is not expected from XXX , they always deliver in time and also early. Please delliver the third item by tomorrow positively.',
#  'Great service and I would like to order another product once more.',
#  'best service and nice person or time to time delivered sunil prajapati is very dutyful person',
#  'abdul rehman Good',
#  'Ramachal store wdl',
#  'Ramchal store wdl',
#  ' XXX has really improved their services. I am happy.',
#  'Harish is very good with deliveries. I am very happy with his service.',
#  'I am totally pleased since it reached me early and without any hassle.',
#  'It was perfectly delivered and that too early. Loved it.',
#  'am all so happy by mr manoj kumar vry gud delvry boy',
#  'gud service by delivery boy',
#  'Delivery boy Kashinath is excellent in his service,punctual and helpful',
#  'The delivery was really very very quick. Keep up the good work ??',
#  'Would like to return the product as the fitting is not good.',
#  'This bhaiya is the best. Very polite and professional.',
#  'Order delivered was before scheduled date...I am happy for the same.',
#  'Awesome delivery speed but product quality not good ..',
#  'Good Service and quick delivery.',
#  'Happy with your delivery boy is good man and respect to customer',
#  'Abdul Rehman nice man',
#  'The delivery was fast and so do the delivery executive',
#  'Experience of XXX product delivery is very nice',
#  'Experience of XXX product delivery is very nice.',
#  'Responded on phone and delivered on time.',
#  'The delivery guy was very polite.',
#  'Too good humble delivery people .such quick delivery totally satisfied',
#  'best service and nice person or time to time delivered sunil prajapati is very dutyful person',
#  'MR.ROOPSHEEL CALLED ME AND FIXED A DELIVERY TIME PERIOD, WHICH HELPED ME TO GET MY ORDER ON TIME!!!',
#  'Excellent and outstanding service',
#  'On time delivered.. skirt is so awesome ND cute looking.',
#  'Delivered before given time, product is same as displayed.',
#  'Very cooperative delivery service',
#  'I am very glad to have my parcel before the delivery date...and that also in the morning time which was so helpful Thank you XXX ',
#  'Excellent service by courier person',
#  'Your service is good.and I m satisfied with you. Thanks',
#  'Timely delivered and polite person',
#  'Good attitude n behaviour your staff',
#  'I always appreciate ur proper delivery time Thanks',
#  'Very happy with the product and the service',
#  'Rajesh was absolutely great. Super service and very cordial. Makes me more loyal to XXX !',
#  "Early delivery, still need to check the product . I'm satisfied with the delivery",
#  'Delivery person is very prompt and well spoken',
#  'Delivery executive did not call before coming',
#  'Inder the delivery person is cooperative',
#  'Plz provide cash nd card on delivery it will be helpful to us or else rest XXX is always awsm',
#  'Wow good ????????',
#  'Service is good and helpful nature ??????',
#  'Happy with his kind cooperation. Thank You.',
#  "I've received my order on time, your team is doing great, Kudos!",
#  'Rakesh bhaiya is sweet and well spoken',
#  'The delivery person is co-operative and peomp delivery.',
#  'Delivered successfully the delivery guy came straight outside my place there was no problem jeans is nice ??',
#  'Nothing but please maintain quality',
#  'He is a very nice man',
#  'Ramachal store wdl',
#  'Yeah I am happy with this XXX ',
#  "I received a wrong product this time. On top of it, I will have to self-ship it in case I want to return it! The fault is XXX 's, so why the hell I have take this trouble!!!!",
#  'Fabric quality is bad',
#  'Logistics and product good in all aspects',
#  'Quality and size as expected...',
#  'Good service, delivery boy was good and delivered before time',
#  'This shoes are awesome perfect size i got',
#  'Its Quality is very Good nd nice. XXX is very Best Online Shopping',
#  'Hassle free withoutcallingand asking where the address he accurately deliveredthe stuff at home.',
#  "It was delivered sooner than I expected. I'm happy with the service as well as with the product. Keep up with the good work. I hope the earphones I bought comes for a long time.",
#  'Very good Experience with XXX .. its always my 1st choice..',
#  'Delivery executive did not deliver the product at my doorstep',
#  "The delivery guy never came to my door he just called me from outside my building. I was working in my office so my phone was on silent mode so couldn't hear his call. He should have come up at the door to deliver the package so that the office boys could have told me about that. This is not at all a good delivery guy or the centre.",
#  'delivery before expcted date am happy',
#  'best service and nice person or time to time delivered sunil prajapati is very dutyful person',
#  'Delivery executive did not call before coming',
#  'In do not have problem with the delivery boy. When I ordered 5-6 years why was 3 size larger sent. This happened 3 time.',
#  'Service is good and fast by a XXX delivery boy Thanks',
#  'The product is good ...so is the service',
#  "Ramachal store wel I'm happy good boy good man I'm happy",
#  'Thank you XXX ',
#  'Product is not good at quality',
#  'Very good service and polite behavior always. Thanks.',
#  'He was very humble and polite',
#  'Your support staff is excellent',
#  'I m satisfied for your delivery boy. Good work.',
#  'Your delivery staff was very courteous and always on time. Best regards to him. Thanks XXX ',
#  'Delivery executive did not deliver the product at my doorstep',
#  "I haven't yet received the product....but have got the delivery message.... How is it possible.... Who should I lodge the complaint to?",
#  'Excellent delivery guy Very nice banti Keep it up',
#  'Excellent delivery guy Very nice banti Keep it up',
#  'Excellent delivery guy Very nice banti Keep it up',
#  'Excellent delivery guy Very nice banti Keep it up',
#  'Quality is too bad',
#  'Delivery executive was rude',
#  'Delivery executive did not wait while I was trying my Try n Buy product',
#  'I have placed for return and will be in my office during the pick up time. So please make sure the delivery excutive pick the product from the address.',
#  'Excellent Delivery service. Perfect fitting and polite answers. Very convenient. Thankyoy!',
#  'It is really good and the price is low and quality is good',
#  'Nice behaviour and honest person',
#  'Product is good and deliveey guys was very polite',
#  "I'm satisfied with the service! Thank you :)",
#  'Thanks for early delivery. Cheers.',
#  'The delivery was prompt and as informed',
#  'Delivery was faster than expected. Very happy.',
#  'He was patient, waited for me to try out before leaving from here.',
#  'Excellent service by delivery person',
#  'Good service by the executive..',
#  'Good , timely communication and delivery.',
#  'Quality is not good',
#  'Excellent experience of timely delievery d humble delievery persons',
#  'Timely delivered. Good work XXX ',
#  "The product which I have got is stupid. I hate it Doesn't looks like how it was shown on the website.",
#  'Good service n cooperative executive',
#  "It's a fantabulous looking bag. I am really very happy to have a bag like this.",
#  'Excellent service....very polite and courteous delivery man.',
#  'Rajib Paul is good delivery boy',
#  'Very polite and humble delivery man, i m very happy with his service.',
#  'Good man I am happy with service',
#  'Thank you for giving such an early delivery.I am pleased with the service provided by XXX .',
#  'Delivery Guy is very good and very friendly nature !!',
#  'Your try and buy scheme does not work for me as I returned an aritcle priced at Rs.521/- in Total bill amount of Rs.3316/- and had to pay Rs. 2893/-. (3316-521 = 2795 ) not taking into consideration that the interest amount would also decrease. Please clarify if possible. Thank you',
#  'All the products i bought throught XXX dint satisfied me. A bad experience and unworthy products',
#  'Delivery time could have been faster',
#  'Delivery guy is polite and good service.',
#  'Very good, neat & clean service by delivery man',
#  'Excellent job... Before time delivery ...',
#  'Thank you...Happy with the delivery...',
#  'Very happy with the services only want to one thing here to arrange geo tagging with order to check the current status of shipping',
#  'Yes Bhagwaan Das executive is very good am happy with his delivery',
#  'Delivery executive did not carry enough change',
#  'No POS machine.. No change of 50rs.. Please give working and compulsury Pos machine to avoid all these troubles',
#  'He is great, always check my availability before delivery and reverse pickup',
#  'He is on time and a decent guy',
#  'Quick and very good service, keep it up',
#  'The guy who comes for delivery is profiessiinal ..',
#  'best service and nice person or time to time delivered sunil prajapati is very dutyful person or time to time delivered sunil prajapati is very dutyful',
#  'He is a very competent agent and well mannered man, most of my items are delivered by him, Thank you XXX ',
#  'Iamveryhappy about your product thank you',
#  'Abhishek shone very nice',
#  'Well behaved delivery boy. happy to get delivery before time',
#  'He is kind and very professional',
#  'Very courteous person. Delivered the good promptly',
#  'I am really happy to hv a shopping on mytra.',
#  "He is good and we'll behaved with professionalism..",
#  'Nice product... And behavior of delivery man is good.',
#  'best service and nice person or time to time delivered sunil prajapati is very dutyful person',
#  'I am happy with the service of the delivery executive. He was before the schedule time and humble',
#  'Product was good..packing was nice..it was right on time.. thank you XXX ??',
#  'Very nice product and good service',
#  'I am happy with the service of the delivery executive',
#  'Nice person. Well behaved. Punctual.',
#  'provide one day delivery or two day delivery on good brands',
#  'Nice guy on time delivery and call before delivery',
#  'Ramachal store wdl good man im happy good boy',
#  'He was very gentle',
#  'Boy was polite n good',
#  'He was very gentle and well behaved',
#  'Very good service happy with the on time dlvry',
#  'best service and nice person or time to time delivered sunil prajapati is very dutyful person or',
#  'Delivered before time, liked it. Good service.',
#  'Prompt delivery, matured,courteous behaviour',
#  'best service and nice person or time to time delivered sunil prajapati is very dutyful person',
#  'Product quality and service are too good. Highly satisfied. Thanks XXX ',
#  'Product is more than my expectation. Its really good??????????',
#  'The delivery is good as expected the person is nice one',
#  'Excellent and on time delivery! THANK YOU',
#  'Delivery time should be mentioned in the messages',
#  "Fast delivery and we'll mannered deleviry boy",
#  'Good service. I am happy with it!!!',
#  'Excellent service..... delivery boy was very nice and polite....keep it up',
#  'Good boy Banti',
#  'The delivery guy was polite and professional.',
#  'Delivered from expected date. Nice experience.',
#  'delivery boy was of good nature.',
#  'Worst material of both kurtas of AKS. Returning it',
#  'Delievred in time. Really happy with the service.',
#  'Delivery guy was patient n waited fir me even though i came late...too much hlpful!',
#  'Overall everything is good.thank you',
#  'The delivery guy was on time and he was polite!',
#  "Order wasn't delayed... And exactly as shown in the picture...",
#  'Delivery executive did not carry enough change',
#  'Delivered before the expected date ?? Product quality is good ?',
#  'Nice collection affordable price and perfect delivery timing.. Good job keep customers happy...',
#  'Thanks for such an early delivery...Keep it up',
#  "Siddhant Maurya is one of the best delivery executives of XXX . He's always on time and shows great respect towards his customers.",
#  'It was more beautiful that i have imagined,happy to shop from XXX ',
#  'Try make good packaging as ZZZ .in does. Would really be appreciated',
#  'Product damaged',
#  'Very much co-operative delivery agent. Thank for early delivery..',
#  'Promised delivery on time.good stuff',
#  'Good service and timely deliveries',
#  'Try to give delivery in 2-3 days will be more good',
#  'Nice person...answers call ans has delivered on time..',
#  "Delivery boy's behaviour was excellent. I m very happy",
#  'Perfect size and happy with service, thank you.',
#  'Ramachal store wdl did good job',
#  'Got my product on time though i was not in the office but still received the same thankyou FAROOQUE',
#  'Delivery executive did not wait while I was trying my Try n Buy product',
#  'He just handed over the product and left! I had not even opened the packet by then. And I thought he was supposed to wait till I try and take the product back if I don’t like it. Disappointed',
#  'I m satisfied with your system of delivery... Keep going on like this.',
#  'fast delivery.... good work.. really appreciate',
#  'The shirts were not properly packed.they were not ironed',
#  'Yes I m very much happy with the delivery',
#  'Very nice..soft spoken and before time delivery',
#  'Called and updated of delivery of products',
#  'Best product and delivered on time',
#  'On time delivery ...delivery boy was polite ...good service',
#  'Excellent service..by Bhanu shikarwar',
#  'The delivery boy is too good his voice talking style very gud n smart boy',
#  'The fitting was not ok',
#  'Service is very good and product is very nice',
#  'Good service! He messaged asoon as he arrived at the offcie. Happy with the service',
#  'I m happy with d delivery. Delivery in time.',
#  'Deliver one whole order in one delivery',
#  'Very fast and satisfactory delivery! !',
#  'I have good experience with mynyra and the one who delivers...',
#  'Thank you for fast delivery ??.',
#  'Quick delivery of my product. Very happy with XXX logistics',
#  'He understood customers timing and availability',
#  "The delivery agent should've call the customer regarding the delivery of the item rather than making the customer to call the agent.",
#  'Excellent and quick delivery .Thanks to delivery guy.',
#  'Good service as well as good communication.',
#  'so happy with services... permanent customer',
#  'Delivery executive was rude',
#  "Perfect products & it's services superb.",
#  'My got debited both in cash as well as card due to less advancement of technical issues of the delivery boy..I want the refund as soon as possible.',
#  'Nice collection accoding to price',
#  'Very kind and co-operative... Mr. Anant',
#  'Delivery Agent should stay longer....so that we can adjust time and come accordingly ...as Delivery is in office time....otherwise itz very Good Service',
#  'He is very humble and nice person',
#  'The delivery guy was very friendly and the girl who called me had a beautiful voice. Two thumbs up',
#  'He was customer oriented. Good',
#  'Good service and we are happy with on time delivery.',
#  'All I want to say is that you are doing a great job...thanks XXX you always make my shopping amazing.you are my favourite loads of love XXX .?',
#  'Material is not so good',
#  'Please give a call before coming for delivery',
#  'Well spoken and patient. Delivers at the doorstep. Efficient.',
#  'Very nice curier support. Well behabed',
#  'Satisfied with the service of delivery executive.Thanks 4 d delivery.',
#  'The person who delivered the dress is extremely polite and delivered the item as per my time convenience..',
#  'Abdul rehman.. Satisfied with the delivery services and prior delivery before Tat',
#  'He is cooperative',
#  'Delivery person was professional',
#  'M Very Hppy n Delivery Uncle is awsum',
#  'Got early delivery, good service',
#  'Delivery was earlier than expected. Very happy with the experience! Good job XXX <3',
#  'Ramachal store wdl im happy good boy good man',
#  'Rajkumar gernal stor very good work thank you',
#  "The product is not like it looked in the image and not at all worth of it's original price",
#  'Not at all happy with your service',
#  "When I get his name as the person who will deliver my product, I just don't worry about address direction. Very helpful in nature.",
#  'Delivery executive did not call before coming',
#  'Delivery executive did not deliver the product at my doorstep',
#  'No prior notification was sent regarding the package delivery and to my surprise i have received a message stating the delivery was successful even though i did not receive it. Need an immediate action on this.',
#  'Very bad product....doesnot worth the money',
#  'Best Delivery Return policy is to good',
#  'I am very bz the boy is smart hanssome and behaviour too good like tha boy also deliverd at door step',
#  'Wrong item delivered',
#  'I am very bz the boy is smart hanssome and behaviour too good like tha boy also deliverd at door step',
#  'The cloth quality is very bad.',
#  'Awesome service.. super happy??',
#  'Excellent delivery system, delivery boy was cooperative, he has delivered the package on time, thanks',
#  'I received this product in less than 24 hours. Good service',
#  'Services are good .very convenient to exchange and return the goods .',
#  'Delivery man is very polite Thank you',
#  'Excellent person.. and humble..',
#  'He is a nice person',
#  'Happy bz the delivery boy come at my door step n his behaviour reaaly good',
#  'I like the product very much.. its awesome... And it diliverd by time i m impressed.',
#  'Awsome service. By your delivery boy',
#  'Genuine way of talking and very polite.',
#  'Delivery executive did not carry enough change',
#  'Product got late delivered, i had to wear it on 12th, i was expecting it to be deliverd on 11th.. moreover the size is too tight for me',
#  "Ramachal store wdl good man and good I'm Happy Ramachal store wdl nice boy",
#  'Please call an hour before delivery',
#  'The dilivery guy and dilivery time both good and satsfactory.',
#  'Please call an hour before delivery',
#  'reallyfantastic personality so good nice person',
#  'Delivery was really quick. Thanks',
#  'Very well behaved and helping nature of the delivery man.',
#  'Good. Hassle free shopping and delivery on XXX .',
#  'the delivery boy character is good',
#  "Everything's up to the mark..nice service",
#  'I am vry hpy the boy is very good',
#  'Having early delivery is always great',
#  'Delivery executive was rude',
#  'Below 500/- material in cash on delivery scheme',
#  'Rajib Paul is good delivery boy',
#  "Amit Sharma he is very nice and polite with lot's of patience. He wait without any complaint . Thumps up for courier vendor",
#  'I am happy. I get it on time. Thank you XXX ',
#  'Rajib Paul is good delivery boy',
#  'The person who came to deliver the product was humble and polite.',
#  'Rajib Paul is good delivery boy',
#  'I did get my previous delivery now ,regarding this shirt i.e i didnt recieve brand name (here and now ) till now .but i got a message saying .it got delivered',
#  'I m very boy the boy behaviour is very smart and good i m really very hpy',
#  'Very quick service. I m highly impressed',
#  'I have order Aline kurti but when ir come to delivered it was dongri...which i have not ordered',
#  'Very much helping and behaved really well. Appreciate their patience.',
#  'He was very flexible for having waited for me till I reached my home for getting the stuff i ordered. Thank you',
#  "I've returned the product but I'm not sure why it says as it's delivered.",
#  'Xavier is an amazing and helpful .. this service is perfect..',
#  'Very good product and discount. XXX rocks.',
#  'Right time delivery.and professional services',
#  'I am satisfied with your service',
#  'Good in fitting and quality but price is little high.',
#  'I got my Nike shoes in good condition, but packing box was is in damage condition which gave me second thought of re use product...',
#  'On time delivery and coperative',
#  'Material is really good... This is the first time I am shopping in XXX . I was really worried as how the material would be. But I am really happy. Thanks.',
#  'Delivery was before time! So very happy!',
#  'Your service and product are good',
#  'The item bought is not working and needs replacement as the left ear piece is not working and not connecting while the Right piece is working and connecting please replace this product Thanks',
#  'Your delivery executive is very nice and good in nature timely delivered courier',
#  'Delivery as promised on time: the executive was polite too.',
#  'Very cooperative delivery executive',
#  'Thanks for quick delivery. I am very much satisfied with response .. thanks XXX . Also delivery person was great attitude and behaviour.. thanks',
#  'Exeeexcellent service by bhanu sikarwar',
#  'he is the best deliveryboy',
#  'Orderded different company item',
#  'Good delivery boy professional and on time. ...good approach towards customer. ..good going keep it up',
#  'Your service facilities are fast and good. Pankaj is nice person.',
#  'Service is very good... There is no suggestions',
#  'Thanks XXX for the fast delivery and good product. ??',
#  'Nice and polite person... I have the product properly.....',
#  'Received order on time. Thank you',
#  'Raj Kumar general store....superb service... Very good person ??',
#  'Received order on time, thank you',
#  'Order has been wrongly delivered',
#  'Dress material is horrible..wasted 1000 for very worst material..will never ever buy from XXX ..also the Person had some issue with credit debit card..had to rush to provide him cash..will never buy from XXX ...worst experience ever',
#  "Everything was good. Except the quality of the dress wasn't that good. It is not either summer or winter material.but I do love how cute the dress was.",
#  'I am very happy with the delivery executive he was good',
#  'The item is not good at all,stitching line is very bad zip,neek line,and the right and left hip of measurement is not same, also material is too transparent no lining inside.I think the designer who stitches this cloths is not experienced.',
#  'Ist time And I am satisfied !!!!',
#  'The boy is very smart behaviour good n also my prsl deluverd at my door step so i m reaaly very hpy good job TEAM XXX AND THE BOY',
#  'Very good service by your delivery boy',
#  'I m so hpy the delivery boy is very good',
#  'I love everything about your site and products. TY!',
#  'I love the Kurta, the price and speedy and courtuos delivery. Thank you guys!',
#  'The material is awesome and it fits amazingly. Value for money.',
#  'um happy.........................................',
#  'Thankkkk youuuuu sooo much XXX for sending my order soooo early.',
#  'It was awesome to deal with such humble executives.',
#  'Delivery person is very kind and gental',
#  'Delivery executive did not call before coming',
#  "Try and buy for first order is free or what...I didn't understand the concept of try n buy",
#  'Wrong size. Horrible quality of top. Want to return',
#  'Good communication n good service',
#  "Exicutive's behavior is very good.",
#  "He's very very efficient and always delivers before time . I think he shud get a promotion",
#  'Very prompt and responsible delivery.im very glad',
#  'Super fast delivery.. Impressed',
#  'Gd prdct...faster delivery...???',
#  'Nothing more to suggest. I am very much satisfied.',
#  'Unprofessional',
#  'Very cooperative delivery boy.',
#  'Wrong size item delivered.',
#  'Nice colour exactly same as picture and fine quality.',
#  'Nice T-shirt very cool n addictive...',
#  'It was awesome to deal with such humble executives.',
#  'Put best to best discount offer',
#  'Very good person hv smiling face and positive attitude.',
#  'He is very nice person.',
#  'I got a worn and torn adidas shoe box',
#  'satisfied with product and service',
#  'Nothing ..good and fast delivery',
#  'Ya it is reliable app.....thankuu XXX for such a multi brand in your app...',
#  'very nice behaviour ....n on tym delivery...m happy',
#  'satisfied with product and service',
#  'The delivery guy Nitin is very good person and good service',
#  'Sounds qulity was not good as compared price.pls try to exchange',
#  'Courier guy was very good',
#  'The product is delivered in time.',
#  'Good experience , person is very honest .',
#  'Products are really beyond my expectations, it fits me perfectly, am loving it. And, the delivery guy was very helpful. Thumbs up for him.',
#  "Getting product on time. I'm happy for XXX .",
#  'Great delivery Timing of all my products',
#  'Please give additional discounts for regular customers.... N keep transparent shrugs for women',
#  'Need some more options in georget',
#  'I have not asked for any reschedule why is this not delivered yet',
#  'Good personality person, before coming he use to call us.',
#  "Courier service as on the exact tym,I mean I got a msg that I will recieve my order today ,n within an hour I got a call...ma'am m here with Ur order. N XXX no doubt u r best at your product????",
#  ' XXX delivery timing are good,it is good place of clothing.',
#  'Very very good yaari excellent. .',
#  'Product is not worth Rs 681',
#  'Delivery before time love the pattern and the dress. Happy with XXX delivery service product',
#  'Great delivery boy he xome at my door step',
#  'Very helpful delivery person Mr. Somenath. Thank you.',
#  'I am happy with service no any other suggetion',
#  'Quality of material is very bad..need to return..no prob in delivery',
#  'Product delivery was quiet good and at ease but as packaging is concern i did’nt get much impress, please make an update. Else thank you so much.',
#  'Very prompt & good service by Manoj Borjle',
#  'Good experience. Easy and convenient',
#  'Very good service by Manoj Borle',
#  'Its was same as I ordered..Very happy to get my new top..:-) :-) :-) :-) :-)',
#  'The delivery guy was prompt and on time always.',
#  'Iam very happy with the service',
#  'The product was so good at this price... I love it. ??',
#  'He is very polite and adjustive. Waiting for me around 2 hr extra without any excuse. 10 out of 10 for politeness, time punctuation, and perfect delivery',
#  "Hii i thought of this is meroon clr but this clr is orange. Any meroon clr kurta is available pls let me know. I am not satisfied with this and u didn't mention this kurta has 2 cuts .",
#  'Dear Team, Mr. Krishna is professional and polite!!! Thank you & Regards Shaik Mohammed Ismail',
#  'very good... delivery boy was excellent',
#  'Delivery executive did not call before coming',
#  'Try do deliver as soon as possible',
#  'Nice sarvise friendly behaviour ??',
#  'The dress is very pretty. The fabric is also very nice. Met my expectations completely ??',
#  'I am happy its very good services',
#  'He is very nice and polite man.He delivered my package on time.Thanks',
#  ' XXX .com is very smart company with all staff',
#  'early delivered and thanks for the currier boy.',
#  'Love the prompt service. Keep up the good work. All the best.',
#  'Love the prompt service. Keep up the good work. All the best.',
#  'Love the prompt service. Keep up the good work. All the best.',
#  'Really helping person who came for delivery. I was not present at home again he arrnged the delivery for me. Thnks',
#  'The delivery boy was very cooperative ??',
#  'Good work XXX ',
#  "Ya it's got delivery on time. Thanks for this great support Varsha shukla",
#  'Try to deliver early thankyou product is in fine condition',
#  'Deliver in time and quality of material are good..',
#  'delivered before time. cheerful delivery agent',
#  'He is very nice and good delivery....',
#  'Very helpful delivery representative.',
#  'The delivery boy delivered me the product on the time which he said. Unlike other delivery boys who do not come on the time said. Totally it was a good and I hope the same delivery boy will come now on daily. Thank you.',
#  'Always call an hour before coming, and tell customer to arrange the change. Also tell if swap machine is available with them or not as someone may not carry cash nd want to pay throgh card',
#  'I am very happy to say that XXX is a very good shopping app and it gave very fast delivery then any other app',
#  'amazing service ....Appreciable',
#  'Guy was very polite and good',
#  ' XXX gives the best service!!!<3',
#  'Product was a top and skirt set.. I only received top of the product. Really sad and annoyed',
#  'On the time delivery and product is too good. I am very happy to see my product. Thank you XXX .',
#  'Very good and coperative delivery man , please increase the incentives, he is very good in his job',
#  'They should say a perfect time. ..the exact time they will deliver the product to us ...',
#  'Good I am fully satisfied with delivery boy',
#  'there has been a slight change in delivery address.the delivery man has came half the way.not fully',
#  'Phone was busy, dint get any call back',
#  'Already doing well..so no suggestion no coments.',
#  'I have received product which I have ordered. I love product.',
#  'Thank you for a fast delivery. I am really happy with it...',
#  'Very good service... I really like him.',
#  'Delivery executive did not wait while I was trying my Try n Buy product',
#  'The delivery executive is very responsible and always well behaved.Thank you XXX ',
#  'The delivery was smooth',
#  'Please kindly make optional online payment service after oder done on cash on delivery basis.so that if the person who has oder is not at delivery address can make online payment and without cancellation his/her order would get delivered',
#  'Love the kurtis and their material. Delivery timing was perfect.I got my parcel on time. No issues at all ??',
#  'The shirt and top I bought ,both are superbbbb!!! Loved it?? And the fitting is too good..',
#  'Satisfied with service provided n product is exactly the same what I had expected..',
#  'Happy with the product and the behaviour of the delivery man. ?? thanks.',
#  'Delivery executive did not carry enough change',
#  'Product quality is very good,jean is little tight but im happy and last thing the courier boy was awesome,he was very helpful and nice ??',
#  'Both the jeans are amazing and is exactly as shown in the picture. So, thank you!',
#  'I am happy for this site for shipping and I expect 15th March delivery but I received 12th March very good delivery time.',
#  'The product is damage nd different',
#  'Good polite person deliver on time thanku XXX .',
#  'Chetan the delivery person is excellent. Very polite. Thanks',
#  'Fastest delivery of the product..',
#  'I was not able to use the try and buy service as the time the person came, it was not suitable for me. I asked him to come before 10 am or after 6:30pm but he refused. But still I bought those shoes and i am satisfied with that.',
#  'The delivery guy is professional',
#  'its delivery process very very better.',
#  'The delivery was on time and hassle free by Mr. Abdul Rehman',
#  'Size issue I want L size plz exchange this',
#  'The delivery person call me on time... Super delivery I love XXX thank you',
#  'Delivery was at time .. it was a good experience .....I am happy with it ..great experience',
#  'Mr. Chandan Deka is very efficient and cordial at service. A big thumbs up for him.',
#  'Good communication skills and timely delivered, overhaul good.',
#  "He's very well behaved.",
#  'The delivery was on time and delivery guy was professional.',
#  'Delivery executive was rude',
#  "It's good and proper size ,those things I expected ,that's are fulfilled",
#  'satisfied with quality and delivery of product',
#  'Stuff is so good,delivery boy is cooperative ...thanku XXX ',
#  'Overall product is quite good ?? and quality of febric worth corsponding to price',
#  'Rajkumar general store .. executive was so polite and humble nice to talk to him',
#  'Reached for the time mentioned.... Delivery boy was good at patience as though i was busy showing my product to my family members...??',
#  'He is very best conversation boy and he is very cool mind',
#  'He is very gentle.. we know him since we have associated with XXX . Thank u??',
#  'No suggestions, Service is very good.',
#  'He is very professional',
#  'Amazing service ..the parcel got delivered in a days time..thank you !',
#  'Quality and look not so impressive as in picture...just ok',
#  'Thanks for prompt and hassle free delivery',
#  'No suggestions good services ...',
#  "As many times different brands have different sizes and you don't know..What size is perfect for you....So.. Happy with Exchange policy and Delivery time ??",
#  'Timely delivery and good service',
#  'The delivery boy name sachin is so hard working and trust worthy',
#  'Fast delivery..very nice..product',
#  'Nice experience after shopping from XXX ',
#  'Delivery personal was very kind as he agreed to deliver my parcel to the other address',
#  'Delivery executive was rude',
#  'Delivery executive did not carry enough change',
#  'Delivery executive did not deliver the product at my doorstep',
#  'Worst delivery.He should atleast come to my door step.He was also unable to provide Rs30 change.Worst experience with XXX ',
#  'Delivery executive was rude',
#  'Delivery executive did not carry enough change',
#  'Delivery executive did not deliver the product at my doorstep',
#  'The product was nice n quality as well',
#  'Delivery executive was rude',
#  'Make sure delivery boy should make a call at a time when he reached not before nd kept us waiting',
#  'Always kn time , delivery person is cooperative and ask for availability',
#  'Delivery before time good job by a delivery boy Thank u',
#  'Nice experience ...thnkxx XXX ',
#  'Delivery on time. Guy very polite .',
#  'He is a good boy.',
#  'Quality is ok I want a xxl size',
#  'Delivery executive did not carry enough change',
#  'Please return this atam not coten shirt',
#  'Raj Kumar store very good person',
#  'Delivery executive was rude',
#  'Delivery executive did not call before coming',
#  "Delivery agent asked to forward the delivery message to him, so that he can give feedback himself. When asked he said there's a server issue if you don't forward the message you need to go to the store for order confirmation. Such a shameless thing to do. Not expected this from XXX agents.",
#  'Delivery person is very good and polite in his talk',
#  'It takes some effort to judge ppl ,, whome to dilever the product,,, dilevery boy understood the instruction very clear and hence dilevered in safe hands ,, well done ??',
#  'Good. Was clear about the parcel and policy of the company regarding returns and try n Buy..',
#  'I like the way you people manage your service. Keep the good work going',
#  'Nothing want to say because all the products of XXX is awsome and yes delivery boy is always gooda and on the time...i am always happy with XXX thats why i love to shopping only at XXX . Thanks XXX for your lovely shopping site.??',
#  'Wonderful customer service...... Kudos to XXX ',
#  'Timely delivery,good experience',
#  'Good job. The delivery man was awesome',
#  'Happy to deliver one day before',
#  'Time taken is too much. Please reduce the day.',
#  'Before time delivery and I am happy about service.',
#  'Executive was very humble. I have problem with the product, Quality is good but image seemed like of light material. Won’t go in Mumbai climate.',
#  'he is coperative',
#  'i m happy wid d service of XXX n quality too,i hav been a vry awesum experience wid XXX ',
#  'He informed me on time. Have good etiquette',
#  'exelent very nice way of talking',
#  'I am happy with the quick delivery',
#  'Loved as it as exactly same ??????',
#  'I ordered not this size L when I ordered S size.',
#  'Sriram , delivered it on time. Happy',
#  'Delivery was actually very fast',
#  'Happy with the behaviour of delivery executive Thanx',
#  'product is good and the delivery man’s behaviour is good..',
#  'Good service by sakshi store Thank you XXX ',
#  "I will give feed back in future bt at this moment it's ok",
#  'I am very happy with the delivery it was earlier than the given time period!!',
#  'Happy with the service delivery',
#  "The delivery executive was professional and polite. That's what a customer expect. Also my delivered product is up to mark. Good job XXX ??",
#  'It was delivered successfully and I am very happy',
#  'Late delivered from what i expected',
#  'Nice behaviour by delivery person',
#  'Dis kurta is very nice similar to showing image .cloth is really awesom. Delivery bayya gave very respect to custmer',
#  "I'm satisfied .. very good service 0",
#  'Very happy with the service n deliver time!!',
#  'Very comfortable. As expected :)',
#  'Delivery person was very humble.',
#  'Delivery man was good and dutiful',
#  "Very satisfying delivery. . The delivery guy's behaviour was very good.. fast and well",
#  'Delivery executive did not carry enough change',
#  'My orders wrong size plz exchange my ordr',
#  'He was good, quick with his job and delivered the item as per time schedul',
#  'Great delivery executive very polite and nice.',
#  'No hassle, just one call and I got the item.',
#  'reallyfantastic personality so good nice person',
#  'It was good experience, my product was delivered to me on time and in convenience of my',
#  'Krishna Kumar very good working i am impress his working',
#  'The man was idiot, when I was on a call and disconnected his call he was calling again and again.. Stupidity was beyond the limits..',
#  'Excellent products , excellent service',
#  'Early delivery.The boy is having the card machine with him which is very good',
#  'I want exchange the size of the items',
#  'GOOD SERVICE..SDA IS VERY HUMBLE',
#  "It's not yet been deliver and says it's been delivered",
#  'fitting and everything is proper',
#  'Osm product and Osm service....??',
#  'Products should be better packaged inside from the vendor',
#  'Delivered on time and such a humble person',
#  "Delivery boy's no. Is not updated...pls update it..",
#  'Appreciate the delivery on time. Thanks',
#  'Delivery was earlier than expected. I am very satisfied with XXX delivery',
#  'Courier boy was really generous and active.',
#  'Timely delivery. And nice servoce by a delovery person Thank you',
#  'I ordered for size 34 . What I got is size no 36.',
#  'Very nice product.... Love with it',
#  'Superb clothe I m very happpy with sirvice ????',
#  'Quick delivery with excellent behavior...',
#  "Jeans fabric is awsum. It's in pure black colour jst lyk image, delivery is fast and good. I am fully satisfy and happy.",
#  'The shoes were not packed properly. The shoe box was half torn and it looked a mess. Also I don’t know if I got a genuine product, it could be a duplicate one. How am I supposed to know that the product which is delivered to me is a genuine one?',
#  'material of d shirt is not good',
#  'delivery for parcel was up to date thanks XXX ',
#  'Ranachal store wdl',
#  'Delivery executive did not call before coming',
#  'Delivery executive did not wait while I was trying my Try n Buy product',
#  'I ordered a white top for try n buy but the delivery guy did not call me before coming and gave the top to my mother at home , took the cash...he said to my mother if i dont like it he will come next day n take it back but he din turn up next day nor called back',
#  'He is quite informative',
#  'Dress is very pretty as shown in the pictures good quality totally worth buying',
#  'Really good experience The delivery boy was really humble :) Thumbs up :)',
#  'Never received the product. Just received "Delivered" message! Delivery executive not reachable!!!',
#  'Before this feedback bu mistake i selected unhappy...please consider it as positive feedback. Thank you',
#  'I would suggest you not to make a limit of purchasing',
#  'Good associate, flexible timing delivery',
#  'nyc professional behavior of the delivery person',
#  'Everything is good about delivery Man',
#  'Why u r collecting delivery charges even in special sale offers',
#  'The material of cloth was good!',
#  'Because of server down problem... 2 times our money has been deducted frm us... Kindly return the extra money back',
#  'Product very in color a lot than what is displayed. If you are not able to deliver what is shown in the cart then please don’t keep that product available to sell.',
#  'Nice quality and delivery. In some product i dont get option for exchange.',
#  'Delivery executive did not deliver the product at my doorstep',
#  'Very Well professional Guy and so polite he speaks.',
#  "It's good.. Order shipped timely.. Done good job by salman...",
#  'The same guy delivered With a well mannered.',
#  'The product was different feel cheated',
#  'I m so happy for early delivery',
#  'The best delievery person I came across.',
#  "Very nice service XXX dealivry boy, good service, I'm fine",
#  'Delivery boy work so well always.',
#  'Delivery executive did not call before coming',
#  'Delivery executive did not wait while I was trying my Try n Buy product',
#  'Your delivery men must have to call before reached to coustomer address. And have to wait untill i try my product.you must have to punish my product delivery men',
#  'His behavior is good and given in time..',
#  'The person could have been more responsive on taking calls.',
#  'Delivery executive did not carry enough change',
#  'I noticed that the delivery men always do not give the change . Also try to give all the orders together',
#  'Delivery executive was rude',
#  "The delivery executive was very very rude and I think XXX shouldn't give such feedback to their customers Hopefully i won't get such thing next time.",
#  'It’s good...keep up the good work.',
#  'Efficiently manages delivery. Very less or no wait time even when he has lots of orders',
#  'Delivery person was good. But the quality of the product is not as expected. The quality of the product is very poor.',
#  'Many products stuffed in single packet . Not at all happy with it . For single orders single packaging should be there .',
#  'Many products stuffed in single packet . Not at all happy with it . For single orders single packaging should be there .',
#  'Many products stuffed in single packet . Not at all happy with it . For single orders single packaging should be there .',
#  'Many products stuffed in single packet . Not at all happy with it . For single orders single packaging should be there .',
#  'Good work.love it. Executive is humble.',
#  'Many products stuffed in single packet . Not at all happy with it . For single orders single packaging should be there .',
#  "Well I'll just endup saying that I am satisfied with product ans service too",
#  'This watch is used watch with many scratches on it ...strange ..i want to return back',
#  'Many products stuffed in single packet . Not at all happy with it . For single orders single packaging should be there .',
#  'Many products stuffed in single packet . Not at all happy with it . For single orders single packaging should be there .',
#  'Guy was very good responsive',
#  'Its a really good product... i am happy with that!!!',
#  'Superb service and very polite person to deal with thanks Rajesh Roy for being so helpful',
#  "Delivery boy's behaviour is nice",
#  'Delivery executive was rude',
#  'Delivery executive did not call before coming',
#  'I just love ur products....Nd ur service.....ur staff ????????',
#  'Very helpful and polite delivery person',
#  'Before time ... good price ... love u XXX ...',
#  'I am verry happy for service boy its verry quickly and fast deleveriy boy',
#  'Delivery is good executive is also good',
#  'Product take much time to deliver',
#  'Quick and convenient delivery',
#  "This complaint is for XXX Logistics.In case of cash on delivery orders, the delivery persons don't carry change at all. For a payment of 440/- I paid a 500/- rupee note, only to be told he has no change.i finally fished our a 50/- rupee note and the delivery boy kept the remaining change.. I do offer tip to these guys but in my own free will, not their inability to render change. XXX logistics please do take note of this and try and improvise.",
#  'my tshirt is small in size.. not so fit..',
#  'Delivery executive did not deliver the product at my doorstep',
#  'Excellent service person.. right on time and very cooperative',
#  'Excellent punctuality and behaviour',
#  'Delivery executive did not call before coming',
#  'Iam very satisfied all this products',
#  'Very co-operative and timely service.',
#  'Super fast delivery. Excellent product',
#  'Executive behaviour is very good',
#  'The pants I order are transparent. How can somewear transparent pants. Please improve your quality. Fitting is good n style.',
#  'excellent product by XXX thanks',
#  "Product is good but colour is some lighter than in the picture I'm happy ur delivery is good It comes two days early",
#  'The dlvry man is so polite ,,',
#  'Very eagar for the service and delivery, soft spoken',
#  'I have kept only two items and returned one item',
#  'The delivery man was really polite and understanding',
#  'Your customers representative is very good person....',
#  'Thanks to the delivery person he is very co-operative. Keep up the good work!!',
#  'Sonu Kumar is an excellent delivery guy. He deserves a promotion.',
#  'Polite professional, extremely happy!',
#  'Delivery person Mr.Nagaraj is good person. I knew him since from 2 to 3 years. Polite and sincere. I thank you once again to him for best service.',
#  "I'm very happy very humble and generous man. He is work very effort and faithfully .I'm very satisfied..",
#  'Delivery executive did not deliver the product at my doorstep',
#  'It was so humble and he was so friendly..',
#  'Happy with the delivery. But not happy with the quality of the product. .looks like duplicTe',
#  'Material is not so good..... Please take it back... And return back money',
#  'Really quick delivery. Thank you for that.',
#  'Excellent job no 1 I m so happy',
#  ' XXX is a good shopping app,the quality is good.',
#  'What should I do, if have size issues with the ordered tshirt?',
#  'Rajkumar General store Very good person and timely delivery. Very soft spoken',
#  'Kurti is osssm. Fabric quality is too good. Loved the product and delighted with XXX services.',
#  ' XXX product is very good .i m so happy mytra service',
#  'Add Try and buy on cash on delivery so we can check the size also it fit as we ordered or not ...',
#  'I got wrong product and it was useless to me, not happy',
#  'I received the product within 4 days and the delivery executive was very helpful. Thank you XXX ...?? ??',
#  'Thank you for giving me before on time',
#  'I am very happy with Sujoy Sarkar’s behaviour',
# ...
#  'Delivery executive was rude',
#  'Delivery executive did not wait while I was trying my Try n Buy product',
#  'Delivery boy told that you can pay the amount after then you can try.',
#  'Thanks for such service. On time delivery.',
#  'The packet was open and I am unsure if the product is all fine or not.',
#  'vey fast delevery boy mr manoj bhatti',
#  'The delivery executive co ordinated and waited till my arrival for delivery of product .',
#  'Deliver product in good condition rather than just in any condition',
#  'its really faster service than i think..i lov e it',
#  'I am very much satisfied with your services .',
#  "Took my phone to do something which he wasn't supposed to do",
#  'Delivery boy was soo good in behaviour.',
#  'I am satisfied with your service.',
#  'Very happy with your service and your delivery system. Thank you',
#  'Delivery executive did not call before coming',
#  'I got delivered massage before i get my product..',
#  'Price should be as per material quality instead of brand orientation. And ofcourse free shipping facilities shouldnot be there from above 1199 but much less',
#  "excellent service. I'm very happy.",
#  'Very good service and very helpful staff and the delivery guy',
#  'Nice quality of top.. delivery guy was also help full and was on time . Thanks',
#  'Your service is best from ZZZ and flipcart. I suggest for myantra is plzz delivered edible items u have only cosmetic and wearing items so this is ur negative point from other online shopping app',
#  'Product on time... great job????',
#  'I am very happy with all the services',
#  'I am happy with this order and deleivery person',
#  'Delivery person card swipping machine not working. Have to walk back to ATM to bring cash.',
#  'He was the best delivery boy I have met so far',
#  'Was not ready to deliver at doorstep as there was only one parcel in my area and mentioned even if XXX site gives home delivery option, it doesn’t pay for such remote place.',
#  'None. Good delivery guy - Somenath !',
#  'I luved the products quality service delivery til now a grt xperiance with XXX .thank u',
#  'loved the product and delivery experience was appreciable.wud shop again',
#  'Kindly dont make your customers fool..The color and quality of the dress which u showed on ur site is totaly different which u delivered to me...so plzz stop making fools.. Very bad product..i am totaly unhappy..',
#  "It's convenient shopping with XXX ",
#  'He delivered on time. Thanks to the delivery guy.',
#  'Prompt delivery and good service',
#  'i like mostly to shopping on XXX . I love it. ????',
#  'Raj Kumar general store is really good person and timely delivered the product. Good work',
#  'Delivery executive did not carry enough change',
#  'The quality of product is very bad .. I decided not to buy any product in myantra.. they are fake products . I inform every one that not buy any product in Myantra ... Seriously a wrost experience',
#  'Good one but the stitchs are not that perfect .. yet superb',
#  'Mst shopping fully satisfied bs meri wish list me jo he un pr jyada discount do na pls',
#  'The order was of blue and yellow checks shirts but blue checks has been delivered and i m not happy with that its very bad experience buying at XXX this time will think again before buying from XXX from now...',
#  'I ordered a blue top but a grey colour top was delivered -_- ..',
#  'The person delivers to my address is regularly same. He is very polite and well mannered',
#  'Credit card machine was not working',
#  'Nice gentleman the delivery guy is and very supportive too.',
#  'excellent service for refund and delivery as well ....much better than other provider like ... YYY and ZZZ ....I certainly recommend to try XXX once.',
#  "I'm impressed bt pictures in XXX app are not crystal clear so it's not understandable properly the detailed design of the dress",
#  'Communication was very good also!',
#  "I received it before the date...I'm Happ for that",
#  'It was delivered on time. The delivery person reattempted and delivered',
#  'Delivery executive did not deliver the product at my doorstep',
#  'Interesting verities, easy delivery.',
#  'Kindly send the delivery executive with change for the amount to be paid by the customer.',
#  'Good job always before the date',
#  'Always delivery before time thts the best thing',
#  'delivery before time.good experience',
#  'I am so happy...i lovely dress??????',
#  'Somnath is excellent in his work.',
#  'Splash t shirt it a good product..??????',
#  'Product description does not match',
#  "I'm always satisfied with XXX .... ????",
#  "Very fast delivery. I'm highly impressed with the service.",
#  'Every service from XXX is good.',
#  'Happy with delivery service. Keep up with good work.',
#  'He was good and got my product without any difficulty :)',
#  'Delivery executive was rude',
#  'Delivery executive did not carry enough change',
#  'Delivery executive did not call before coming',
#  'The delivery executive was yelling at me for not having change and when I asked him for card on delivery he yelled at me more. This is not the kind of treatment I expect I am going to lodge a complaint on the platforms about XXX and this kind of service.',
#  'He was very polite nd ur service is nice',
#  'product is good and your service is awesome',
#  'Have known him since many years. He is a very polite and professional individual. Always smiling and very cooperative.',
#  'thnx XXX .. ??',
#  'Nice behaviour of delivery person',
#  'Delivery person is so good and present to me.',
#  'On time. Good delivery. Nice behavior',
#  'Along with the Pickup i had a return parcel as well... I have still not got any mesaage sugessting that return has been picked up.',
#  "I'm very haapy and satisfied about the product and also the delivery was on time.It was really very good",
#  'delievery boy is prompt and good',
#  'Quality is not good but service was good.',
#  'Anil Sodaye was a very responsible and responsive delivery boy who took a lot of effort to call Me is as I was unavailable and then coordinated with me for the delivery',
#  'The product was awsm and was delivered way before the delivery date so satisfied from the delivery',
#  'Wrong product delivered.',
#  'The delivery person is very decent and polite',
#  'this guy is delivered very fast',
#  'Packing a little visible inside*** Before time delivery *****',
#  'The delivery guy was very courteous and polite.',
#  'Good communication between customer and delivery boy',
#  "It was my 2nd time order for same range of items but like last time this time also wrong sizes were sent of parx t shirts.I'm very unhappy wd dt.pls send me the correct sizes of the same.thank u",
#  'Delivery executive was rude',
#  'Always remind me for the FEEDBACK Act as OVERSMART',
#  "Delivery executive should inform the customer, that he'll be coming in a particular time slot. So that we can schedule our day.",
#  'Always happy to receive item from Jitender Yadav ??',
#  'I am liking the colour and combination but problems I found are as follows :- Inner fabric (top)is not body friendly. It was very transparent. Sleeves was a bit tight.',
#  'It was pretty good and fast and the quality is awesome.',
#  'Nice person with nice attitude towards customers',
#  'Very good service... Very good nature.. very good communication',
#  'As expected.. n the person delivered the order was quiet patient n polite..',
#  'Well done brother keep it up.....',
#  'keep it up. the delivery is great.',
#  'very polite delivery person not in hurry ??',
#  'Superb service and fast delivery',
#  'Please deliver other orders Also on time',
#  'Thank you XXX . I received my order before time. I am happy',
#  'So satisfied with the product as well as service.',
#  'They are always on time and very polite.',
#  'Services are exceptionally fantastic very courteous with very g[d manners. I wish him all success',
#  'Need improvement in quality products',
#  'On time delivery, product is similar as I bought from spykar showroom andheri chakala.. thanks for the best quality',
#  'Product quality is bad. Want to return immediately.',
#  'The product was good',
#  'Delivery executive was rude',
#  'Delivery executive did not wait while I was trying my Try n Buy product',
#  "I've faced him twice in 3 days and this is absurd that I had to convince the guy both the times to come upstairs for products bought for 'Try & Buy' and out of that, the second time I had to go down 3 floors to receive it. Am I supposed to try clothes on ground floor while I live on 3rd floor ? Please do not send him to me again, I won't pick his calls.",
#  'He was a very nice person.',
#  'I ordered for try and buy..but no the packet it is not written so delivery boy do not give me this option..',
#  'Delivery is before time..keep it up',
#  'Quality is soo bed...I am not happy ur services n ur quality is too bed..',
#  'I ordered 3 items got only 2. Why is it so ? Not fair enough.',
#  'Perfect delivery with perfect product',
#  'Very prompt delivery and very polite delivery staff',
#  'Delivery boy was soft sopken, well behaved...nice',
#  'M happy with the product.. i have seen many attractive product in this site..',
#  'Delivery was given before time. Very good service..',
#  'Very cooperative.product is very good.material as well as fitting is perfect',
#  'Service is very good and service staff is excellent person',
#  'Delivery person called and deliver the product on time and looks professional. Good work.',
#  'He is a decent boy',
#  'Delivery is to fast. That’s great thanks',
#  'The delivery guy is very friendly and supportive. He always carries a smile and treats really well.',
#  'Delivery executive was rude',
#  'Delivery executive did not call before coming',
#  'Delivery executive did not wait while I was trying my Try n Buy product',
#  'Delivery person refuse to wait as I ordered try and buy product. This is very unprofessional and unacceptable. Not satisfied with the process at all.',
#  'polite and panctual delivery guy..packing is good..happy with the service',
#  "The product wasn't good, a sound was audible in the shoe like babies shoes",
#  'Item deliver by time i am thankful to you',
#  'Colour is a bit different from the photo',
#  'Good . minimum delivery time taken',
#  'Material is good as I thought. I am happy with it.',
#  'The packaging was pathetic .... Dress is all crumbled up.... Very bad packaging .... Package is also crumbled up plus the dress material is horrible.... Very bad .... 1 st time buying from XXX .. Very bad experience ... Not happy',
#  'While u are delivering thé product plz check it',
#  "Send all the orders at a time.. Don't split the items..and have multiple delivery...",
#  'Thank you so much for the delivery at the reception..',
#  'this is very good. I am very Happy',
#  'Happy with the Lipbalm no doubt , but gift has to be bigger , how I can someone gift the little mascara if they get the samll gift like these',
#  'Very very good delivered and produced',
#  'The product was good and properly packed and the product delivery was on time .awesome work thanku so much',
#  'Awesome products! But u should work on your packing a Bit!! ??',
#  'Please continue with your smooth service.',
#  "It's was a perfect size and I really love it... But gst is too high.",
#  'Wonderfully delivered in no time',
#  'Delivery executive did not wait while I was trying my Try n Buy product',
#  'Delivery executive did not carry enough change',
#  'Delivery was quick & delivery boy was also good',
#  'Nice behavior and good attitude..',
#  'the size was ok. i am happy with the delivery service.',
#  'No additional feedback... awesome service..cheers',
#  'First of all I didn’t get my order how do you write that your product is successfully delivered.. I ordered US POLO shirt but you have sent me the Roadster. I didn’t like. Pls refund my money',
#  'Delivery executive did not call before coming',
#  'I called him and told him to come after 6. But still he came before that',
#  'I have got the broken lipstick..i want to exchange it..or take it back..because it is of no use to me..',
#  'He came according to my convenience and delivered me the placed order before time.Thank you',
#  'Very nice clothes and design my family very happy Thanks XXX ',
#  'Material is good and no issue of size.',
#  'I m happy and i enjoyed shopping through XXX ',
#  'I am happy with this product and delevery so fast thank you',
#  'kindly mention the exact time for delivery !!',
#  "The delivery associate Govind Sonkar, was kind enough to change the mode of payment from COD to Net Banking as I wasn't available to pick up the package from him.",
#  'Only one T-shirt received and one pending',
#  'Nice n I like XXX keep up d work',
#  'Please rate of low had been requested for western dress. Since it was the first time',
#  'Delivery executive did not call before coming',
#  'Delivery executive did not wait while I was trying my Try n Buy product',
#  'Didnt receive call...it was trail n back offer...n it was just delivered as normal',
#  'Good service.quick delivery.thanku XXX .',
#  "Product delivered well. I'm happy",
#  'Good service as always by Farooq',
#  'Keep up the good work Anil safi',
#  'Krishna manages very well all my deliveries.answer my calls and updates for all deliverables',
#  "It's very fine and cool but I'm disappointed because of you mention try option deliver time but he said no. Plz clear it",
#  'I m very happy with this product and XXX .',
#  'I get it very early??happy to have this... Thank you',
#  'The delivery guy is very professinal..',
#  'Satisfied with product quality and price',
#  'Very professional, very punctual and accommodating delivery executive. He comes to deliver all my orders and is a very pleasing personality.',
#  'Fantastic person. Very happy. Every time should send these type of executive. Very very happy . Great gesture by him.',
#  'He is Cooperative.',
#  'Please purchase shap machine your employees',
#  'I am happy with XXX delivery service..',
#  'I ordered a white shirt and it has some black stains.',
#  'Good attitude n behaviour your staff',
#  'I dont like this product . Want to return.',
#  'Again and again same problem I am facing gift packing is not good not satisfied',
#  'He is very polite nature i hope he will always acheive their acheivement in their life',
#  'product got dilevred on time i happy with the service',
#  'Good service ...would love to shop again',
#  'The packing shirt is not iron it look lik old shirt full of wrinkles shirt packed in side cover also very bad..',
#  'Prompt without problem delivery.great experience',
#  'He actually called me up because last time I changed the address the best part is that he remembered and called me again and confirmed the delivery address',
#  'Delivery boy was very friendly in behaviour',
#  'The serivice was fast and good..!! I like it ??',
#  "I want to return this product because I didn't suit me",
#  'The delivery was good',
#  'Good person and very responsible in making the deliverys',
#  'Courier guy is very polite and helpful nature. Satisfied with the services.',
#  'it was on time and delivery boy treated respectfully',
#  'The delivery staff was polite and professional',
#  "I'm very happy to say that product of XXX was awsm",
#  ' XXX delievery services in rohtak are excellent.',
#  'Mr Sharma is amazing ..he came back just in one call to server his duty..excellent delivery..I am very happy with the service he provided today',
#  'Delivery person is good woth services',
#  'I am satisfied and thank you ??',
#  'He was well mannered',
#  'Decent guy with nice behaviour and good response.',
#  'Good service and co-operative delivery boys',
#  'Happy got delivery before the time',
#  'Delivery executive did not carry enough change',
#  "He didn't come to my hostel...but others delivery man comes till my room ..",
#  'Delivwry guy was polite and he is performing his work well.',
#  'i am so happy . excellent delivery service',
#  'Prompt delivery and courteous delivery Man',
#  'Delivery executive was rude',
#  'U should have an option to change size at the same price because I wanted 1 size smallee but did not get the same offer..in fact I had to pay 55 rupees more..',
#  ...]

# %%
file = open('csvf.csv','w')
file1= open ('not_same.csv', 'w')
    
with open("B.csv", "r") as f:
    # Skip the first line
    f.readline()
    for i, line in enumerate(f):
       # print (float(line.split(",")[3]))
        if str(line.split(",")[3]) in Feedbacks:
            file.write(line)  
        else:
            file1.write(line)

# %%
Dict= pd.read_csv("/Users/kamakshibansal/A5.csv")
same= pd.read_csv("/Users/kamakshibansal/csvf.csv")
# # merged_inner = pd.merge(left=same,right=Dict, left_on='feedback', right_on='feedback')\

# %%
s1=pd.DataFrame()
s1["feedback"]= Dict.feedback.unique()
s1.to_csv("s1.csv")

# %%
s1.shape
# Out:
# (91768, 1)

# %%
s2=pd.DataFrame()
s2["feedback"]= same.feedback.unique()
s2.to_csv("s2.csv")

# %%
merged_left1 = pd.merge(s2,s1,on='feedback', how='inner' )

# %%
merged_left1.shape
# Out:
# (12606, 1)

# %%
Dict2= Dict.drop_duplicates(subset=['feedback'], keep='first')

# %%
Dict2.shape
# Out:
# (91768, 4)

# %%
same.shape
# Out:
# (17030, 13)

# %%
Dict2.to_csv("A6.csv")

# %%
merged_left = pd.merge(same,Dict2,on='feedback', how='inner' )
# merged_left= pd.concat([same,Dict],axis=1)

merged_left
# Out:
#        data_id  survey request id survey received date  \
# 0      2462650        135319513.0            09-Apr-18
# 1      2462723        135339055.0            09-Apr-18
# 2      2462798        135363796.0            09-Apr-18
# 3      2463010        135424151.0            09-Apr-18
# 4      2463212        135500214.0            09-Apr-18
# 5      2463312        135541271.0            09-Apr-18
# 6      2463315        135541370.0            09-Apr-18
# 7      2463361        135564981.0            09-Apr-18
# 8      2463442        135595681.0            09-Apr-18
# 9      2463458        135602450.0            09-Apr-18
# 10     2463556        135646508.0            09-Apr-18
# 11     2463607        135671600.0            09-Apr-18
# 12     2463697        135721874.0            09-Apr-18
# 13     2463770        135758392.0            09-Apr-18
# 14     2463825        135886226.0            10-Apr-18
# 15     2463937        135920249.0            10-Apr-18
# 16     2463950        135924841.0            10-Apr-18
# 17     2464078        135966436.0            10-Apr-18
# 18     2464093        135970830.0            10-Apr-18
# 19     2464160        135995919.0            10-Apr-18
# 20     2464268        136025694.0            10-Apr-18
# 21     2464370        136074952.0            10-Apr-18
# 22     2464372        136075684.0            10-Apr-18
# 23     2464396        136085877.0            10-Apr-18
# 24     2464443        136105338.0            10-Apr-18
# 25     2464457        136109295.0            10-Apr-18
# 26     2464568        136160848.0            10-Apr-18
# 27     2464578        136164238.0            10-Apr-18
# 28     2464927        136380675.0            11-Apr-18
# 29     2464964        136396949.0            11-Apr-18
# ...        ...                ...                  ...
# 17000  2461512                NaN           12/04/2018
# 17001  2461535                NaN           12/04/2018
# 17002  2461590                NaN           13/04/2018
# 17003  2461650                NaN           13/04/2018
# 17004  2461699                NaN           13/04/2018
# 17005  2461706                NaN           13/04/2018
# 17006  2461729                NaN           13/04/2018
# 17007  2461787                NaN           14/04/2018
# 17008  2461812                NaN           14/04/2018
# 17009  2461816                NaN           14/04/2018
# 17010  2461830                NaN           14/04/2018
# 17011  2461936                NaN           14/04/2018
# 17012  2461833                NaN           14/04/2018
# 17013  2461842                NaN           14/04/2018
# 17014  2461993                NaN           15/04/2018
# 17015  2462042                NaN           15/04/2018
# 17016  2462054                NaN           15/04/2018
# 17017  2462098                NaN           15/04/2018
# 17018  2462107                NaN           16/04/2018
# 17019  2462190                NaN           16/04/2018
# 17020  2462215                NaN           16/04/2018
# 17021  2462227                NaN           16/04/2018
# 17022  2462266                NaN           16/04/2018
# 17023  2462328                NaN           16/04/2018
# 17024  2462338                NaN           16/04/2018
# 17025  2462369                NaN           17/04/2018
# 17026  2462390                NaN           17/04/2018
# 17027  2462449                NaN           17/04/2018
# 17028  2462457                NaN           17/04/2018
# 17029  2462631                NaN           17/04/2018
#
#                                              feedback survey name  \
# 0      Delivery executive did not carry enough change           C
# 1      Delivery executive did not carry enough change           C
# 2      Delivery executive did not carry enough change           C
# 3      Delivery executive did not carry enough change           C
# 4      Delivery executive did not carry enough change           C
# 5      Delivery executive did not carry enough change           C
# 6      Delivery executive did not carry enough change           C
# 7      Delivery executive did not carry enough change           C
# 8      Delivery executive did not carry enough change           C
# 9      Delivery executive did not carry enough change           C
# 10     Delivery executive did not carry enough change           C
# 11     Delivery executive did not carry enough change           C
# 12     Delivery executive did not carry enough change           C
# 13     Delivery executive did not carry enough change           C
# 14     Delivery executive did not carry enough change           C
# 15     Delivery executive did not carry enough change           C
# 16     Delivery executive did not carry enough change           C
# 17     Delivery executive did not carry enough change           C
# 18     Delivery executive did not carry enough change           C
# 19     Delivery executive did not carry enough change           C
# 20     Delivery executive did not carry enough change           C
# 21     Delivery executive did not carry enough change           C
# 22     Delivery executive did not carry enough change           C
# 23     Delivery executive did not carry enough change           C
# 24     Delivery executive did not carry enough change           C
# 25     Delivery executive did not carry enough change           C
# 26     Delivery executive did not carry enough change           C
# 27     Delivery executive did not carry enough change           C
# 28     Delivery executive did not carry enough change           C
# 29     Delivery executive did not carry enough change           C
# ...                                               ...         ...
# 17000                                          Good.            D
# 17001                                   It's awesome            D
# 17002                                      Very nice            D
# 17003                             Very quick delivery           D
# 17004                             Amazing experience            R
# 17005                                It was very nice           D
# 17006                                 Best experience           D
# 17007                               Very satisfactory           D
# 17008                                   Very good....           D
# 17009                                     Very good n           D
# 17010                                   Good product            D
# 17011                                   Good product            D
# 17012                                 Perfect quality           D
# 17013                                      It's good            D
# 17014                                    Awesome.....           D
# 17015                                    It's superb            D
# 17016                                      I like it.           D
# 17017                                   Nice service            D
# 17018                               Too late delivery           D
# 17019                               Superb experience           D
# 17020                                      Very good.           D
# 17021                             Very late delivery            D
# 17022                               Colour difference           D
# 17023                               Very fast refund            R
# 17024                               Very fast refund            R
# 17025                                      Awesome...           D
# 17026                                       It's good           D
# 17027                       Wrong product delivered.            D
# 17028                                         Thanks            R
# 17029                                      Thank you            D
#
#        delivery type survey created date   id(r id)  option_id  question_id  \
# 0                NaN                 NaN  7799807.0        4.0          2.0
# 1                NaN                 NaN  8047793.0        4.0          2.0
# 2                NaN                 NaN  7805643.0        4.0          2.0
# 3                NaN                 NaN  7816190.0        4.0          2.0
# 4                NaN                 NaN  7809105.0        4.0          2.0
# 5                NaN                 NaN  7811052.0        4.0          2.0
# 6                NaN                 NaN  7811778.0        4.0          2.0
# 7                NaN                 NaN  7812478.0        4.0          2.0
# 8                NaN                 NaN  7820934.0        4.0          2.0
# 9                NaN                 NaN  7818697.0        4.0          2.0
# 10               NaN                 NaN  7817893.0        4.0          2.0
# 11               NaN                 NaN  7820452.0        4.0          2.0
# 12               NaN                 NaN  7824364.0        4.0          2.0
# 13               NaN                 NaN  7826957.0        4.0          2.0
# 14               NaN                 NaN  7834566.0        4.0          2.0
# 15               NaN                 NaN  7837517.0        4.0          2.0
# 16               NaN                 NaN  7847159.0        4.0          2.0
# 17               NaN                 NaN  7840378.0        4.0          2.0
# 18               NaN                 NaN  7855803.0        4.0          2.0
# 19               NaN                 NaN  7876984.0        4.0          2.0
# 20               NaN                 NaN  7844294.0        4.0          2.0
# 21               NaN                 NaN  7849385.0        4.0          2.0
# 22               NaN                 NaN  7846549.0        4.0          2.0
# 23               NaN                 NaN  7847154.0        4.0          2.0
# 24               NaN                 NaN  7854200.0        4.0          2.0
# 25               NaN                 NaN  7849502.0        4.0          2.0
# 26               NaN                 NaN  7852719.0        4.0          2.0
# 27               NaN                 NaN  7853151.0        4.0          2.0
# 28               NaN                 NaN  7871146.0        4.0          2.0
# 29               NaN                 NaN  7870897.0        4.0          2.0
# ...              ...                 ...        ...        ...          ...
# 17000            NaN                 NaN        NaN        NaN          NaN
# 17001            NaN                 NaN        NaN        NaN          NaN
# 17002            NaN                 NaN        NaN        NaN          NaN
# 17003            NaN                 NaN        NaN        NaN          NaN
# 17004            NaN                 NaN        NaN        NaN          NaN
# 17005            NaN                 NaN        NaN        NaN          NaN
# 17006            NaN                 NaN        NaN        NaN          NaN
# 17007            NaN                 NaN        NaN        NaN          NaN
# 17008            NaN                 NaN        NaN        NaN          NaN
# 17009            NaN                 NaN        NaN        NaN          NaN
# 17010            NaN                 NaN        NaN        NaN          NaN
# 17011            NaN                 NaN        NaN        NaN          NaN
# 17012            NaN                 NaN        NaN        NaN          NaN
# 17013            NaN                 NaN        NaN        NaN          NaN
# 17014            NaN                 NaN        NaN        NaN          NaN
# 17015            NaN                 NaN        NaN        NaN          NaN
# 17016            NaN                 NaN        NaN        NaN          NaN
# 17017            NaN                 NaN        NaN        NaN          NaN
# 17018            NaN                 NaN        NaN        NaN          NaN
# 17019            NaN                 NaN        NaN        NaN          NaN
# 17020            NaN                 NaN        NaN        NaN          NaN
# 17021            NaN                 NaN        NaN        NaN          NaN
# 17022            NaN                 NaN        NaN        NaN          NaN
# 17023            NaN                 NaN        NaN        NaN          NaN
# 17024            NaN                 NaN        NaN        NaN          NaN
# 17025            NaN                 NaN        NaN        NaN          NaN
# 17026            NaN                 NaN        NaN        NaN          NaN
# 17027            NaN                 NaN        NaN        NaN          NaN
# 17028            NaN                 NaN        NaN        NaN          NaN
# 17029            NaN                 NaN        NaN        NaN          NaN
#
#         shipment_id  length         orderno sentiment   category  \
# 0      2.022319e+09    46.0             NaN  Negative   Delivery
# 1      2.023120e+09    46.0             NaN  Negative   Delivery
# 2      2.023022e+09    46.0             NaN  Negative   Delivery
# 3      2.022149e+09    46.0             NaN  Negative   Delivery
# 4      2.022545e+09    46.0             NaN  Negative   Delivery
# 5      2.022937e+09    46.0             NaN  Negative   Delivery
# 6      2.022816e+09    46.0             NaN  Negative   Delivery
# 7      2.022080e+09    46.0             NaN  Negative   Delivery
# 8      2.022992e+09    46.0             NaN  Negative   Delivery
# 9      2.022992e+09    46.0             NaN  Negative   Delivery
# 10     2.022939e+09    46.0             NaN  Negative   Delivery
# 11     2.022332e+09    46.0             NaN  Negative   Delivery
# 12     2.022546e+09    46.0             NaN  Negative   Delivery
# 13     2.022535e+09    46.0             NaN  Negative   Delivery
# 14     2.023352e+09    46.0             NaN  Negative   Delivery
# 15     2.022785e+09    46.0             NaN  Negative   Delivery
# 16     2.023290e+09    46.0             NaN  Negative   Delivery
# 17     2.022796e+09    46.0             NaN  Negative   Delivery
# 18     2.023057e+09    46.0             NaN  Negative   Delivery
# 19     2.022862e+09    46.0             NaN  Negative   Delivery
# 20     2.022893e+09    46.0             NaN  Negative   Delivery
# 21     2.022796e+09    46.0             NaN  Negative   Delivery
# 22     2.022185e+09    46.0             NaN  Negative   Delivery
# 23     2.022998e+09    46.0             NaN  Negative   Delivery
# 24     2.022951e+09    46.0             NaN  Negative   Delivery
# 25     2.022730e+09    46.0             NaN  Negative   Delivery
# 26     2.023093e+09    46.0             NaN  Negative   Delivery
# 27     2.022961e+09    46.0             NaN  Negative   Delivery
# 28     2.023136e+09    46.0             NaN  Negative   Delivery
# 29     2.023351e+09    46.0             NaN  Negative   Delivery
# ...             ...     ...             ...       ...        ...
# 17000           NaN     NaN  JBNC0004486489  Positive    General
# 17001           NaN     NaN     MLJC3308456  Positive    General
# 17002           NaN     NaN     MLJC3284389  Positive    General
# 17003           NaN     NaN  JBNP0003892480  Positive   Delivery
# 17004           NaN     NaN        59503641  Positive    General
# 17005           NaN     NaN     MLJC3293326  Positive    General
# 17006           NaN     NaN     MLJC3315150  Positive    General
# 17007           NaN     NaN     MLJP3721668  Positive    General
# 17008           NaN     NaN     MLJC3259517  Positive    General
# 17009           NaN     NaN     MLJC3352629  Positive    General
# 17010           NaN     NaN  JBNC0004482745  Positive   Category
# 17011           NaN     NaN     MLJC3307714  Positive   Category
# 17012           NaN     NaN     MLJC3361611  Positive   Category
# 17013           NaN     NaN     MLJC3307096  Positive    General
# 17014           NaN     NaN     MLJP3744421  Positive    General
# 17015           NaN     NaN     MLJP3763955  Positive    General
# 17016           NaN     NaN     MLJC3363702  Positive    General
# 17017           NaN     NaN     MLJP3741350  Positive    General
# 17018           NaN     NaN     MLJP3634908  Negative   Delivery
# 17019           NaN     NaN     MLJP3794449  Positive    General
# 17020           NaN     NaN     MLJC3390494  Positive    General
# 17021           NaN     NaN     MLJP3727561  Negative   Delivery
# 17022           NaN     NaN     MLJP3772132  Negative    Catalog
# 17023           NaN     NaN        59824053  Positive    Finance
# 17024           NaN     NaN        59823555  Positive    Finance
# 17025           NaN     NaN     MLJP3778227  Positive    General
# 17026           NaN     NaN     MLJP3830468  Positive    General
# 17027           NaN     NaN     MLJC3300656  Negative  Warehouse
# 17028           NaN     NaN        59848670  Positive    General
# 17029           NaN     NaN  JBNP0003901812  Positive    General
#
#                          Sub_category
# 0              Delivery boy behaviour
# 1              Delivery boy behaviour
# 2              Delivery boy behaviour
# 3              Delivery boy behaviour
# 4              Delivery boy behaviour
# 5              Delivery boy behaviour
# 6              Delivery boy behaviour
# 7              Delivery boy behaviour
# 8              Delivery boy behaviour
# 9              Delivery boy behaviour
# 10             Delivery boy behaviour
# 11             Delivery boy behaviour
# 12             Delivery boy behaviour
# 13             Delivery boy behaviour
# 14             Delivery boy behaviour
# 15             Delivery boy behaviour
# 16             Delivery boy behaviour
# 17             Delivery boy behaviour
# 18             Delivery boy behaviour
# 19             Delivery boy behaviour
# 20             Delivery boy behaviour
# 21             Delivery boy behaviour
# 22             Delivery boy behaviour
# 23             Delivery boy behaviour
# 24             Delivery boy behaviour
# 25             Delivery boy behaviour
# 26             Delivery boy behaviour
# 27             Delivery boy behaviour
# 28             Delivery boy behaviour
# 29             Delivery boy behaviour
# ...                               ...
# 17000                             NaN
# 17001                             NaN
# 17002                             NaN
# 17003                  Delivery speed
# 17004                             NaN
# 17005                             NaN
# 17006                             NaN
# 17007                             NaN
# 17008                             NaN
# 17009                             NaN
# 17010                 Product quality
# 17011                 Product quality
# 17012                 Product quality
# 17013                             NaN
# 17014                             NaN
# 17015                             NaN
# 17016                             NaN
# 17017                             NaN
# 17018                  Delivery speed
# 17019                             NaN
# 17020                             NaN
# 17021                  Delivery speed
# 17022  Catalog image - Product/Colour
# 17023                     Refund time
# 17024                     Refund time
# 17025                             NaN
# 17026                             NaN
# 17027          Received wrong product
# 17028                             NaN
# 17029                             NaN
#
# [17030 rows x 16 columns]

# %%
merged_left.to_csv("merged.csv")

# %%
merged_left.shape
# Out:
# (17030, 16)

# %%
PredSenti= pd.read_csv("/Users/kamakshibansal/PredictedSentiment_Test.csv")
not_same= pd.read_csv("/Users/kamakshibansal/not_same.csv")

# %%
PredSenti1= PredSenti.drop_duplicates(subset=['feedback'], keep='first')

# %%
PredSenti1.head(2)
# Out:
#    Unnamed: 0                                           feedback sentiment
# 0           0          Fast Delivery. Always before time. Thanks  Positive
# 1           1  I have order brown shoe .And I got olive green...  Negative

# %%
PredSenti.shape
# Out:
# (25629, 3)

# %%
PredSenti1.shape
# Out:
# (21064, 3)

# %%
not_same.shape
# Out:
# (8599, 13)

# %%
not_same.head(2)
# Out:
#    data_id  survey request id survey received date  \
# 0  2462636        135244581.0            09-Apr-18
# 1  2462637        135314508.0            09-Apr-18
#
#                                             feedback survey name  \
# 0          Fast Delivery. Always before time. Thanks           C
# 1  I have order brown shoe .And I got olive green...           C
#
#    delivery type survey created date   id(r id)  option_id  question_id  \
# 0            NaN                 NaN  7831504.0        8.0          3.0
# 1            NaN                 NaN  7797769.0        8.0          3.0
#
#     shipment_id  length orderno
# 0  2.022860e+09    41.0     NaN
# 1  2.022813e+09    51.0     NaN

# %%
merged_second = pd.merge(not_same,PredSenti1,on='feedback', how='inner' )

# %%
merged_second.shape
# Out:
# (8599, 15)

# %%
merged_second.to_csv("merged_second.csv")

# %% [markdown]
# # For category and sub-category of not_same file

# %%
MReport1= pd.read_csv("/Users/kamakshibansal/Downloads/MReport1.csv")
MReport2= pd.read_csv("/Users/kamakshibansal/Downloads/MReport2.csv")
MReport3= pd.read_csv("/Users/kamakshibansal/Downloads/MReport3.csv")
MReport4= pd.read_csv("/Users/kamakshibansal/Downloads/MReport4.csv")
MReport5= pd.read_csv("/Users/kamakshibansal/Downloads/MReport5.csv")

# %%
MReport1.feedback = MReport1.feedback.replace('\s+', ' ', regex=True)
MReport2.feedback = MReport2.feedback.replace('\s+', ' ', regex=True)
MReport3.feedback = MReport3.feedback.replace('\s+', ' ', regex=True)
MReport4.feedback = MReport4.feedback.replace('\s+', ' ', regex=True)
MReport5.feedback = MReport5.feedback.replace('\s+', ' ', regex=True)

# %%
MReport11 = pd.DataFrame()
MReport11["feedback"]= MReport1["feedback"]
MReport11["Answer2_1"]= MReport1["Answer2_1"]
MReport11["sentiment"]= MReport1["Answer_1"]


MReport22 = pd.DataFrame()
MReport22["feedback"]= MReport2["feedback"]
MReport22["Answer2_1"]= MReport2["Answer2_1"]
MReport22["sentiment"]= MReport2["Answer_1"]

MReport33 = pd.DataFrame()
MReport33["feedback"]= MReport3["feedback"]
MReport33["Answer2_1"]= MReport3["Answer2_1"]
MReport33["sentiment"]= MReport3["Answer_1"]


MReport44 = pd.DataFrame()
MReport44["feedback"]= MReport4["feedback"]
MReport44["Answer2_1"]= MReport4["Answer2_1"]
MReport44["sentiment"]= MReport4["Answer_1"]

MReport55 = pd.DataFrame()
MReport55["feedback"]= MReport5["feedback"]
MReport55["Answer2_1"]= MReport5["Answer2_1"]
MReport55["sentiment"]= MReport5["Answer_1"]

New_MReport=pd.concat([MReport11,MReport22, MReport33, MReport44, MReport55])
New_MReport.to_csv("New_MReport_cat.csv")

# %%
mapFile= pd.read_csv("/Users/kamakshibansal/Mapfile.csv")

# %%
merged_third = pd.merge(New_MReport,mapFile,on='Answer2_1', how='inner' )

# %%
merged_third.shape
# Out:
# (23378, 5)

# %%
merged_third.to_csv("mergerd_third.csv")

# %%
merged_third1= merged_third.drop_duplicates(subset=['feedback'], keep='first')

# %%
merged_third1.shape
# Out:
# (22253, 5)

# %%
merged_fourth = pd.merge(not_same,merged_third1,on='feedback', how='inner' )

# %%
merged_fourth.shape
# Out:
# (6566, 17)

# %%
merged_fourth.to_csv("merged_fourth.csv")

# %%
File1= pd.read_csv("/Users/kamakshibansal/merged.csv")
File2= pd.read_csv("/Users/kamakshibansal/merged_fourth.csv")

# %%
Merged_version1=pd.concat([File1,File2])

# %%
Merged_version1.to_csv("Merged_version1.csv")

# %%
data_id = []
with open("merged_fourth.csv", "r") as f:
    r = pd.read_csv(f)
    data_id = list(r["data_id"])

# %%
data_id
# Out:
# [2462636,
#  2463224,
#  2463226,
#  2463228,
#  2463238,
#  2462637,
#  2462640,
#  2462641,
#  2462643,
#  2462644,
#  2462645,
#  2462647,
#  2462649,
#  2462653,
#  2462655,
#  2462656,
#  2462658,
#  2462659,
#  2462660,
#  2462661,
#  2462662,
#  2462664,
#  2462666,
#  2462671,
#  2462672,
#  2462673,
#  2462674,
#  2462675,
#  2462678,
#  2462679,
#  2462681,
#  2462682,
#  2462683,
#  2462685,
#  2462687,
#  2462689,
#  2462693,
#  2462695,
#  2462696,
#  2462698,
#  2462699,
#  2462700,
#  2462701,
#  2462702,
#  2462704,
#  2462705,
#  2462707,
#  2462708,
#  2462710,
#  2462711,
#  2462712,
#  2462713,
#  2462714,
#  2462715,
#  2462716,
#  2462717,
#  2462718,
#  2462719,
#  2462721,
#  2462727,
#  2462729,
#  2462730,
#  2462731,
#  2462732,
#  2462733,
#  2462734,
#  2462736,
#  2462739,
#  2462741,
#  2462743,
#  2462744,
#  2462746,
#  2462748,
#  2462749,
#  2462750,
#  2462752,
#  2462753,
#  2462755,
#  2462756,
#  2462757,
#  2462758,
#  2462760,
#  2462763,
#  2462764,
#  2462765,
#  2462766,
#  2462768,
#  2462770,
#  2462771,
#  2462773,
#  2462778,
#  2462779,
#  2462780,
#  2462783,
#  2462784,
#  2462785,
#  2462787,
#  2462789,
#  2462790,
#  2462791,
#  2462793,
#  2462796,
#  2462801,
#  2462803,
#  2462804,
#  2462805,
#  2462806,
#  2462807,
#  2462809,
#  2462811,
#  2462812,
#  2462814,
#  2462816,
#  2462817,
#  2462818,
#  2462826,
#  2462827,
#  2462828,
#  2462830,
#  2462831,
#  2462833,
#  2462834,
#  2462835,
#  2462836,
#  2462838,
#  2462839,
#  2462840,
#  2462841,
#  2462846,
#  2462847,
#  2462849,
#  2462850,
#  2462851,
#  2462852,
#  2462853,
#  2462854,
#  2462855,
#  2462857,
#  2462860,
#  2462861,
#  2462862,
#  2462858,
#  2462859,
#  2462863,
#  2462864,
#  2462865,
#  2462866,
#  2462867,
#  2462868,
#  2462870,
#  2462871,
#  2462873,
#  2462874,
#  2462875,
#  2462876,
#  2462877,
#  2462878,
#  2462879,
#  2462881,
#  2462882,
#  2462883,
#  2462884,
#  2462885,
#  2462886,
#  2462887,
#  2462888,
#  2462889,
#  2462891,
#  2462893,
#  2462895,
#  2462896,
#  2462897,
#  2462898,
#  2462899,
#  2462900,
#  2462901,
#  2462903,
#  2462904,
#  2462906,
#  2462910,
#  2462911,
#  2462912,
#  2462914,
#  2462915,
#  2462916,
#  2462917,
#  2462918,
#  2462919,
#  2462920,
#  2462921,
#  2462922,
#  2462923,
#  2462924,
#  2462925,
#  2462926,
#  2462927,
#  2462928,
#  2462929,
#  2462930,
#  2462933,
#  2462934,
#  2462935,
#  2462937,
#  2462940,
#  2462941,
#  2462943,
#  2462944,
#  2462945,
#  2462946,
#  2462947,
#  2462948,
#  2462949,
#  2462950,
#  2462951,
#  2462953,
#  2462955,
#  2462956,
#  2462958,
#  2462959,
#  2462960,
#  2462961,
#  2462962,
#  2462963,
#  2462964,
#  2462965,
#  2462966,
#  2462968,
#  2462969,
#  2462970,
#  2462971,
#  2462972,
#  2462975,
#  2462976,
#  2462977,
#  2462978,
#  2462979,
#  2462982,
#  2462983,
#  2462984,
#  2462988,
#  2462985,
#  2462986,
#  2462987,
#  2462989,
#  2462992,
#  2462993,
#  2462996,
#  2462997,
#  2463000,
#  2463002,
#  2463004,
#  2463006,
#  2463007,
#  2463008,
#  2463013,
#  2463014,
#  2463015,
#  2463016,
#  2463017,
#  2463019,
#  2463020,
#  2463021,
#  2463023,
#  2463024,
#  2463029,
#  2463031,
#  2463032,
#  2463034,
#  2463036,
#  2463037,
#  2463038,
#  2463039,
#  2463040,
#  2463041,
#  2463042,
#  2463043,
#  2463044,
#  2463045,
#  2463047,
#  2463049,
#  2463050,
#  2463051,
#  2463052,
#  2463053,
#  2463054,
#  2463055,
#  2463057,
#  2463058,
#  2463059,
#  2463060,
#  2463061,
#  2463062,
#  2463063,
#  2463064,
#  2463065,
#  2463066,
#  2463067,
#  2463068,
#  2463069,
#  2463070,
#  2463071,
#  2463072,
#  2463073,
#  2463074,
#  2463075,
#  2463077,
#  2463078,
#  2463079,
#  2463080,
#  2463081,
#  2463082,
#  2463083,
#  2463084,
#  2463086,
#  2465102,
#  2463085,
#  2463088,
#  2463089,
#  2463090,
#  2463091,
#  2463092,
#  2463093,
#  2463094,
#  2463098,
#  2463101,
#  2463103,
#  2463104,
#  2463106,
#  2463107,
#  2463108,
#  2463109,
#  2463112,
#  2463114,
#  2463115,
#  2463117,
#  2463118,
#  2463119,
#  2463120,
#  2463121,
#  2463122,
#  2463126,
#  2463127,
#  2463128,
#  2463129,
#  2463131,
#  2463135,
#  2463137,
#  2463134,
#  2463136,
#  2463139,
#  2463140,
#  2463141,
#  2463142,
#  2463145,
#  2463146,
#  2463147,
#  2463148,
#  2463149,
#  2463150,
#  2463152,
#  2463153,
#  2463155,
#  2463156,
#  2463157,
#  2463159,
#  2463160,
#  2463162,
#  2463163,
#  2463164,
#  2463165,
#  2463166,
#  2463167,
#  2463178,
#  2463169,
#  2463170,
#  2463171,
#  2463172,
#  2463173,
#  2463174,
#  2463175,
#  2463177,
#  2463179,
#  2463181,
#  2463182,
#  2463183,
#  2463184,
#  2463186,
#  2463187,
#  2463189,
#  2463752,
#  2463753,
#  2463754,
#  2464675,
#  2464676,
#  2465533,
#  2465732,
#  2467205,
#  2467206,
#  2467207,
#  2467694,
#  2468051,
#  2468053,
#  2468054,
#  2463190,
#  2463192,
#  2463193,
#  2463194,
#  2463195,
#  2463196,
#  2463197,
#  2463199,
#  2463203,
#  2463205,
#  2463206,
#  2463207,
#  2463208,
#  2463209,
#  2463210,
#  2463213,
#  2463214,
#  2463215,
#  2463216,
#  2463217,
#  2463218,
#  2463219,
#  2463220,
#  2463223,
#  2463225,
#  2463227,
#  2463231,
#  2463235,
#  2463236,
#  2463237,
#  2463239,
#  2463240,
#  2463242,
#  2463243,
#  2463244,
#  2463245,
#  2463246,
#  2463248,
#  2463249,
#  2463250,
#  2463252,
#  2463253,
#  2463254,
#  2463257,
#  2463258,
#  2463259,
#  2463260,
#  2463262,
#  2463263,
#  2463265,
#  2463266,
#  2463267,
#  2463270,
#  2463271,
#  2463272,
#  2463273,
#  2463274,
#  2463275,
#  2463276,
#  2463277,
#  2463279,
#  2463280,
#  2463281,
#  2463282,
#  2463283,
#  2463285,
#  2463286,
#  2463287,
#  2463289,
#  2463290,
#  2463291,
#  2463292,
#  2463293,
#  2463294,
#  2463297,
#  2463298,
#  2463300,
#  2463301,
#  2463303,
#  2463304,
#  2463305,
#  2463306,
#  2463309,
#  2463310,
#  2463313,
#  2463316,
#  2463317,
#  2463318,
#  2463320,
#  2463321,
#  2463322,
#  2463323,
#  2463324,
#  2463327,
#  2463328,
#  2463329,
#  2463331,
#  2463332,
#  2463335,
#  2463334,
#  2463337,
#  2463340,
#  2463341,
#  2463342,
#  2463343,
#  2463344,
#  2463345,
#  2463347,
#  2463349,
#  2463350,
#  2463351,
#  2463352,
#  2463353,
#  2463354,
#  2463356,
#  2463357,
#  2463358,
#  2463362,
#  2463365,
#  2463366,
#  2463367,
#  2463368,
#  2463369,
#  2463370,
#  2463371,
#  2463374,
#  2463375,
#  2463376,
#  2463377,
#  2463378,
#  2463379,
#  2463380,
#  2463381,
#  2463382,
#  2463383,
#  2463384,
#  2463385,
#  2463386,
#  2463387,
#  2463390,
#  2463392,
#  2463393,
#  2463395,
#  2463397,
#  2463398,
#  2463400,
#  2463405,
#  2463401,
#  2463402,
#  2463403,
#  2463404,
#  2463406,
#  2463408,
#  2463407,
#  2463411,
#  2463412,
#  2463413,
#  2463414,
#  2463415,
#  2463418,
#  2463416,
#  2463417,
#  2463419,
#  2463421,
#  2463422,
#  2463423,
#  2463424,
#  2463426,
#  2463427,
#  2463428,
#  2463429,
#  2463430,
#  2463432,
#  2463434,
#  2463435,
#  2463436,
#  2463437,
#  2463440,
#  2463441,
#  2463444,
#  2463446,
#  2463447,
#  2463448,
#  2463449,
#  2463450,
#  2463451,
#  2463452,
#  2463453,
#  2463455,
#  2463456,
#  2463461,
#  2463462,
#  2463463,
#  2463464,
#  2463465,
#  2463467,
#  2463466,
#  2463468,
#  2463469,
#  2463471,
#  2463472,
#  2463473,
#  2463476,
#  2463477,
#  2463478,
#  2463479,
#  2463480,
#  2463481,
#  2463484,
#  2463487,
#  2463488,
#  2463489,
#  2463490,
#  2463491,
#  2463492,
#  2463494,
#  2463495,
#  2463497,
#  2463498,
#  2463499,
#  2463501,
#  2463502,
#  2463503,
#  2463505,
#  2463506,
#  2463507,
#  2463509,
#  2463510,
#  2463511,
#  2463513,
#  2463516,
#  2463517,
#  2463518,
#  2463519,
#  2463521,
#  2463523,
#  2463524,
#  2463525,
#  2463526,
#  2463527,
#  2463528,
#  2463530,
#  2463531,
#  2463532,
#  2463533,
#  2463534,
#  2463535,
#  2463536,
#  2463537,
#  2463538,
#  2463539,
#  2463543,
#  2463544,
#  2463547,
#  2463548,
#  2463551,
#  2463553,
#  2463555,
#  2463557,
#  2463558,
#  2463559,
#  2463562,
#  2463563,
#  2463564,
#  2463565,
#  2463566,
#  2463568,
#  2463569,
#  2463570,
#  2463571,
#  2463572,
#  2463573,
#  2463575,
#  2463579,
#  2463580,
#  2463581,
#  2463582,
#  2463583,
#  2463584,
#  2463585,
#  2463586,
#  2463587,
#  2463588,
#  2463589,
#  2463590,
#  2463592,
#  2463593,
#  2463595,
#  2463596,
#  2463598,
#  2463599,
#  2463601,
#  2463602,
#  2463604,
#  2463610,
#  2463611,
#  2463612,
#  2463613,
#  2463614,
#  2463615,
#  2463616,
#  2463618,
#  2463619,
#  2463620,
#  2463621,
#  2463622,
#  2463623,
#  2463625,
#  2463626,
#  2463628,
#  2463629,
#  2463633,
#  2463636,
#  2463637,
#  2463639,
#  2463642,
#  2463647,
#  2463648,
#  2463649,
#  2463651,
#  2463652,
#  2463655,
#  2463656,
#  2463657,
#  2463658,
#  2463659,
#  2463660,
#  2463662,
#  2463663,
#  2463664,
#  2463667,
#  2463668,
#  2463670,
#  2463673,
#  2463674,
#  2464951,
#  2463675,
#  2463678,
#  2463680,
#  2463681,
#  2463682,
#  2463683,
#  2463685,
#  2463686,
#  2463687,
#  2463689,
#  2463690,
#  2463691,
#  2463692,
#  2463696,
#  2463700,
#  2463704,
#  2463705,
#  2463707,
#  2463712,
#  2463715,
#  2463716,
#  2463717,
#  2463718,
#  2463719,
#  2463720,
#  2463721,
#  2463726,
#  2463728,
#  2463729,
#  2463730,
#  2463731,
#  2463733,
#  2463734,
#  2463736,
#  2463738,
#  2463739,
#  2463740,
#  2463742,
#  2463743,
#  2463744,
#  2463745,
#  2463746,
#  2463748,
#  2463750,
#  2463755,
#  2463758,
#  2463759,
#  2463762,
#  2463763,
#  2463764,
#  2463766,
#  2463767,
#  2463769,
#  2463777,
#  2463778,
#  2463779,
#  2463780,
#  2463783,
#  2463784,
#  2463786,
#  2463789,
#  2463791,
#  2463793,
#  2463794,
#  2463795,
#  2463796,
#  2463797,
#  2463798,
#  2463801,
#  2463802,
#  2463803,
#  2463805,
#  2463806,
#  2463807,
#  2463808,
#  2463811,
#  2463813,
#  2463814,
#  2463815,
#  2463816,
#  2463817,
#  2463818,
#  2463819,
#  2463821,
#  2463822,
#  2463824,
#  2463827,
#  2463829,
#  2463831,
#  2463832,
#  2463834,
#  2463835,
#  2463836,
#  2463837,
#  2463838,
#  2463839,
#  2463840,
#  2463842,
#  2463843,
#  2463844,
#  2463845,
#  2463846,
#  2463847,
#  2463848,
#  2463849,
#  2463850,
#  2463853,
#  2463854,
#  2463857,
#  2463859,
#  2463861,
#  2463862,
#  2463863,
#  2463864,
#  2463865,
#  2463867,
#  2463868,
#  2463869,
#  2463871,
#  2463872,
#  2463874,
#  2463875,
#  2463876,
#  2463877,
#  2463878,
#  2463879,
#  2463880,
#  2463881,
#  2463883,
#  2463884,
#  2463885,
#  2463886,
#  2463887,
#  2463888,
#  2463890,
#  2463891,
#  2463893,
#  2463894,
#  2463896,
#  2463897,
#  2463902,
#  2463903,
#  2463904,
#  2463905,
#  2463906,
#  2463907,
#  2463909,
#  2463911,
#  2463912,
#  2463913,
#  2463914,
#  2463915,
#  2463916,
#  2463917,
#  2463918,
#  2463919,
#  2463920,
#  2463921,
#  2463922,
#  2463923,
#  2463926,
#  2463927,
#  2463928,
#  2463929,
#  2463930,
#  2463932,
#  2463933,
#  2463934,
#  2463935,
#  2463938,
#  2463939,
#  2463941,
#  2463942,
#  2463943,
#  2463945,
#  2463946,
#  2463947,
#  2463948,
#  2463949,
#  2463952,
#  2463956,
#  2463957,
#  2463958,
#  2463963,
#  2463968,
#  2463969,
#  2463971,
#  2463973,
#  2463974,
#  2463976,
#  2463978,
#  2463980,
#  2463981,
#  2463982,
#  2463983,
#  2463985,
#  2463986,
#  2463988,
#  2463989,
#  2463991,
#  2463992,
#  2463993,
#  2463994,
#  2463995,
#  2463996,
#  2463998,
#  2463999,
#  2464000,
#  2464001,
#  2464002,
#  2464003,
#  2464004,
#  2464005,
#  2464006,
#  2464007,
#  2464008,
#  2464009,
#  2464010,
#  2464012,
#  2464014,
#  2464015,
#  2464016,
#  2464017,
#  2464021,
#  2464022,
#  2464024,
#  2464025,
#  2464026,
#  2464027,
#  2464028,
#  2464030,
#  2464031,
#  2464033,
#  2464034,
#  2464037,
#  2464038,
#  2466062,
#  2464039,
#  2464040,
#  2464041,
#  2464044,
#  2464045,
#  2464046,
#  2464047,
#  2464048,
#  2464050,
#  2464051,
#  2464052,
#  2464053,
#  2464054,
#  2464056,
#  2464060,
#  2464061,
#  2464062,
#  2464064,
#  2464065,
#  2464067,
#  2464068,
#  2464072,
#  2464074,
#  2464075,
#  ...]

# %%
file = open('same1.csv','w')
file1= open ('not_same2.csv', 'w')
    
with open("merged_second.csv", "r") as f:
    # Skip the first line
    f.readline()
    for i, line in enumerate(f):
       # print (float(line.split(",")[3]))
        if int(line.split(",")[0]) in data_id:
            file.write(line)  
        else:
            file1.write(line)

# %%
mergerd_third= pd.read_csv("/Users/kamakshibansal/mergerd_third.csv")
Dict= pd.read_csv("/Users/kamakshibansal/A5.csv")

# %%
mergerd_third = mergerd_third.drop('Answer2_1', axis=1)
mergerd_third.head(2)
# Out:
#                                     feedback sentiment  category  \
# 0  Fast Delivery. Always before time. Thanks  Positive  Delivery
# 1          Great. Delivered with in 13 hours  Positive  Delivery
#
#      sub_category
# 0  Delivery speed
# 1  Delivery speed

# %%
Dict.head(2)
# Out:
#                                             feedback sentiment  category  \
# 0  I got my order vey fast,the day after i placed...  Positive  Category
# 1                                  XXX is amazing...  Positive   General
#
#       sub_category
# 0  Product quality
# 1              NaN

# %%
Train=pd.concat([Dict,mergerd_third])

# %%
Train["sub_category"] = Train["sub_category"].fillna("null")

# %%
Train.to_csv("Train_cat.csv")
Train.shape
# Out:
# (150450, 4)

# %%
Test= pd.read_csv("/Users/kamakshibansal/not_same2.csv")

# %%
Test.shape
# Out:
# (2032, 14)

# %%
Test.head(2)
# Out:
#    data_id  survey request id survey received date  \
# 0  2462639        135315888.0            09-Apr-18
# 1  2462642        135318061.0            09-Apr-18
#
#                                             feedback survey name  \
# 0  Delivery is on expected date and that what I l...           C
# 1  It's very good Packing condition some times.qu...           C
#
#    delivery type survey created date   id(r id)  option_id  question_id  \
# 0            NaN                 NaN  7816906.0        8.0          3.0
# 1            NaN                 NaN  7797966.0        8.0          3.0
#
#     shipment_id  length orderno sentiment
# 0  2.022986e+09   138.0     NaN  Positive
# 1  2.022943e+09    60.0     NaN  Positive

# %%
import re, nltk
from sklearn.feature_extraction.text import CountVectorizer        
from nltk.stem.porter import PorterStemmer


stemmer = PorterStemmer()
def stem_tokens(tokens, stemmer):
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

def tokenize(text):
    # remove non letters
    text = re.sub("[^a-zA-Z]", " ", text)
    # tokenize
    tokens = nltk.word_tokenize(text)
    # stem
    stems = stem_tokens(tokens, stemmer)
    return stems

vectorizer = CountVectorizer(
    analyzer = 'word',
    tokenizer = tokenize,
    lowercase = True,
    stop_words = 'english',
    max_features = 85
)

# %%
corpus_data_features = vectorizer.fit_transform(Train.feedback.tolist() + Test.feedback.tolist())

# %%
corpus_data_features_nd = corpus_data_features.toarray()
corpus_data_features_nd.shape
# Out:
# (152482, 85)

# %%
vocab = vectorizer.get_feature_names()
print (vocab)
# Out:
# ['alway', 'ani', 'awesom', 'bad', 'befor', 'best', 'boy', 'brand', 'buy', 'colour', 'come', 'custom', 'day', 'deliv', 'deliveri', 'did', 'differ', 'easi', 'excel', 'exchang', 'execut', 'expect', 'experi', 'fast', 'fit', 'good', 'got', 'great', 'guy', 'ha', 'happi', 'help', 'hi', 'improv', 'item', 'jabong', 'just', 'like', 'look', 'love', 'm', 'materi', 'money', 'myntra', 'n', 'need', 'nice', 'onli', 'order', 'pack', 'packag', 'perfect', 'person', 'pleas', 'polit', 'price', 'process', 'product', 'provid', 'qualiti', 'quick', 'realli', 'receiv', 'refund', 'return', 's', 'satisfi', 'servic', 'shirt', 'shoe', 'shop', 'size', 't', 'thank', 'thi', 'time', 'tri', 'u', 'use', 'veri', 'wa', 'want', 'work', 'wrong', 'xxx']

# %%
dist = np.sum(corpus_data_features_nd, axis=0)

# For each, print the vocabulary word and the number of times it 
# appears in the training set
for tag, count in zip(vocab, dist):
    print (count, tag)
# Out:
# 3547 alway
# 2841 ani
# 4608 awesom
# 3006 bad
# 5604 befor
# 4710 best
# 6900 boy
# 2795 brand
# 3985 buy
# 2984 colour
# 3100 come
# 5717 custom
# 4174 day
# 14753 deliv
# 46596 deliveri
# 4400 did
# 3282 differ
# 2474 easi
# 5513 excel
# 4425 exchang
# 6031 execut
# 4070 expect
# 7052 experi
# 6610 fast
# 4014 fit
# 43964 good
# 5009 got
# 5775 great
# 4821 guy
# 3289 ha
# 10639 happi
# 2334 help
# 2302 hi
# 2654 improv
# 4405 item
# 4824 jabong
# 3223 just
# 7385 like
# 3581 look
# 6298 love
# 3974 m
# 2698 materi
# 2493 money
# 4591 myntra
# 5616 n
# 2405 need
# 11087 nice
# 2630 onli
# 12448 order
# 2441 pack
# 3008 packag
# 2600 perfect
# 6768 person
# 5977 pleas
# 3279 polit
# 4255 price
# 3053 process
# 47745 product
# 2508 provid
# 12522 qualiti
# 2882 quick
# 5197 realli
# 6627 receiv
# 4790 refund
# 9062 return
# 3985 s
# 4134 satisfi
# 21851 servic
# 2682 shirt
# 3212 shoe
# 6598 shop
# 10380 size
# 4606 t
# 11907 thank
# 12033 thi
# 18534 time
# 3823 tri
# 3607 u
# 3018 use
# 32719 veri
# 32065 wa
# 2677 want
# 3360 work
# 2437 wrong
# 8764 xxx

# %% [markdown]
# # Logistic Regression for Category prediction

# %%
from sklearn.cross_validation import train_test_split

# remember that corpus_data_features_nd contains all of our original train and test data, so we need to exclude
# the unlabeled test entries
X_train1, X_test1, y_train1, y_test1  = train_test_split(
    corpus_data_features_nd[0:len(Train)], 
    Train.category,
    train_size=0.85, 
    random_state=1234)

# %%
from sklearn.linear_model import LogisticRegression

log_model1 = LogisticRegression()
log_model1 = log_model.fit(X=X_train1, y=y_train1)

# %%
y_pred1 = log_model1.predict(X_test1)

# %%
y_pred1
# Out:
# array(['General', 'Delivery', 'Delivery', ..., 'Catalog', 'General', 'CE'],
#       dtype=object)

# %%
from sklearn import metrics, cross_validation
metrics.accuracy_score(y_test1, y_pred1)
# Out:
# 0.7140198511166254

# %%
# train classifier
log_model1 = LogisticRegression()
log_model1 = log_model1.fit(X=corpus_data_features_nd[0:len(Train)], y=Train.category)

# %%
test_pred1 = log_model1.predict(corpus_data_features_nd[len(Train):])

# %%
test_pred1.shape
# Out:
# (2032,)

# %%
Test["category"]= test_pred1

# %%
Test
# Out:
#       data_id  survey request id survey received date  \
# 0     2462639        135315888.0            09-Apr-18
# 1     2462642        135318061.0            09-Apr-18
# 2     2462646        135318991.0            09-Apr-18
# 3     2462648        135319199.0            09-Apr-18
# 4     2462652        135320109.0            09-Apr-18
# 5     2466538        137240739.0            13-Apr-18
# 6     2462665        135322815.0            09-Apr-18
# 7     2462668        135323451.0            09-Apr-18
# 8     2462670        135323713.0            09-Apr-18
# 9     2462676        135324910.0            09-Apr-18
# 10    2462680        135326709.0            09-Apr-18
# 11    2462684        135327122.0            09-Apr-18
# 12    2462686        135328640.0            09-Apr-18
# 13    2462688        135329650.0            09-Apr-18
# 14    2462690        135330082.0            09-Apr-18
# 15    2462694        135330863.0            09-Apr-18
# 16    2462697        135331780.0            09-Apr-18
# 17    2462703        135332678.0            09-Apr-18
# 18    2462706        135334915.0            09-Apr-18
# 19    2462709        135335228.0            09-Apr-18
# 20    2462720        135338352.0            09-Apr-18
# 21    2462728        135340079.0            09-Apr-18
# 22    2462735        135342893.0            09-Apr-18
# 23    2462737        135343514.0            09-Apr-18
# 24    2462742        135345463.0            09-Apr-18
# 25    2462745        135346099.0            09-Apr-18
# 26    2462747        135346725.0            09-Apr-18
# 27    2462754        135348266.0            09-Apr-18
# 28    2463475        135606900.0            09-Apr-18
# 29    2462759        135350874.0            09-Apr-18
# ...       ...                ...                  ...
# 2002  2462509                NaN           17/04/2018
# 2003  2462511                NaN           17/04/2018
# 2004  2462516                NaN           17/04/2018
# 2005  2462524                NaN           17/04/2018
# 2006  2462528                NaN           17/04/2018
# 2007  2462531                NaN           17/04/2018
# 2008  2462533                NaN           17/04/2018
# 2009  2462534                NaN           17/04/2018
# 2010  2462549                NaN           17/04/2018
# 2011  2462550                NaN           17/04/2018
# 2012  2462557                NaN           17/04/2018
# 2013  2462565                NaN           17/04/2018
# 2014  2462566                NaN           17/04/2018
# 2015  2462567                NaN           17/04/2018
# 2016  2462571                NaN           17/04/2018
# 2017  2462581                NaN           17/04/2018
# 2018  2462585                NaN           17/04/2018
# 2019  2462586                NaN           17/04/2018
# 2020  2462590                NaN           17/04/2018
# 2021  2462596                NaN           17/04/2018
# 2022  2462597                NaN           17/04/2018
# 2023  2462598                NaN           17/04/2018
# 2024  2462600                NaN           17/04/2018
# 2025  2462605                NaN           17/04/2018
# 2026  2462609                NaN           17/04/2018
# 2027  2462611                NaN           17/04/2018
# 2028  2462616                NaN           17/04/2018
# 2029  2462618                NaN           17/04/2018
# 2030  2462623                NaN           17/04/2018
# 2031  2462632                NaN           17/04/2018
#
#                                                feedback survey name  \
# 0     Delivery is on expected date and that what I l...           C
# 1     It's very good Packing condition some times.qu...           C
# 2     This was my first purchase with myantra and I ...           C
# 3           Product is nice and delivery man was awsome           C
# 4                            Delivery is good and fast.           C
# 5                            Delivery is good and fast.           C
# 6                   On time with nice product i love it           C
# 7     This item which received it's very poor qualit...           C
# 8     Delivery man is very polite and very fast service           C
# 9     Delivery executive was very polite and profess...           C
# 10    Awesome product.really appreciate the service ...           C
# 11    Delivery boy is good and delivery timing is al...           C
# 12    This boy is very gud and delivers on time..i m...           C
# 13                    The delivery boy was very polite.           C
# 14          Very polite and delivered it before time...           C
# 15          timely delivered by well mannered executive           C
# 16    Very smooth delivery.. very good experience al...           C
# 17    On time delievery...would like to appreciate t...           C
# 18    I love this product and very early delivery th...           C
# 19    A delivery guy was too good. On time delivery....           C
# 20    The quality and delivery was just the way I ex...           C
# 21    Delivery is always on time. Cloth material is ...           C
# 22    Fast delivery and very happy with the apparel....           C
# 23    Awesome stuff and a good delivery person farro...           C
# 24                                He is always on time.           C
# 25    Nice service given by you and it was timely gi...           C
# 26    The delivery was on time..n d delivery boy was...           C
# 27    Great courtesy. Nice communication and timely ...           C
# 28    Great courtesy. Nice communication and timely ...           C
# 29    Osm delivery The product is really good I luv ...           C
# ...                                                 ...         ...
# 2002  Everything is perfect. Quality of product, fit...           D
# 2003  All is excellent .... product as well as delivery           D
# 2004                                             nice n           D
# 2005  The dresses I ordered were amazing. Such a goo...           D
# 2006  As seen the product , i don't think its genuin...           D
# 2007  the delivered size was wrong and could not exc...           D
# 2008                                   Extremely good!!           D
# 2009  Product is really good. And always delivered o...           D
# 2010  The delivery was good. And the product was als...           D
# 2011  Wrong item delivered. Customer care suggests c...           D
# 2012  Awesome!!! Liked using the app with ease & ver...           D
# 2013  according to you refund is initiated and refun...           R
# 2014  What a discount on original Nike product , ama...           D
# 2015            Awesome product & fast delivery service           D
# 2016  In the website its written cotton pantties whe...           D
# 2017  It is mentioned on app that this bra is padded...           D
# 2018  My daughter was anxiously awaiting the product...           D
# 2019  I like the Jabong app search experience. It is...           D
# 2020  Discount..delivery before time...cash on deliv...           D
# 2021  Excellent original quality.... Loads of variet...           D
# 2022  I placed order for 2 numbers of the same item ...           D
# 2023  The product looks exactly like it's in the ima...           D
# 2024  It’s a very nice skirt and I got it six days b...           D
# 2025  I ordered 34 size belt and delivery was 38 siz...           R
# 2026       Fast delivery.good product/price.keep it up.           D
# 2027  Recieved a defective product..it is used...I a...           D
# 2028                  Very good quality for the price.            D
# 2029  Totally dissatisfied. Bad quality, XS size is ...           D
# 2030  Very nice products and ease of exchange of the...           R
# 2031                                   Fully satisfied            D
#
#       delivery type survey created date   id(r id)  option_id  question_id  \
# 0               NaN                 NaN  7816906.0        8.0          3.0
# 1               NaN                 NaN  7797966.0        8.0          3.0
# 2               NaN                 NaN  7798168.0        8.0          3.0
# 3               NaN                 NaN  7798604.0        8.0          3.0
# 4               NaN                 NaN  7798150.0        8.0          3.0
# 5               NaN                 NaN  7934069.0        8.0          3.0
# 6               NaN                 NaN  7798444.0        8.0          3.0
# 7               NaN                 NaN  7823381.0        8.0          3.0
# 8               NaN                 NaN  7813418.0        8.0          3.0
# 9               NaN                 NaN  7798573.0        8.0          3.0
# 10              NaN                 NaN  7799970.0        8.0          3.0
# 11              NaN                 NaN  7806814.0        8.0          3.0
# 12              NaN                 NaN  7799690.0        8.0          3.0
# 13              NaN                 NaN  7798972.0        8.0          3.0
# 14              NaN                 NaN  7799014.0        8.0          3.0
# 15              NaN                 NaN  7799586.0        8.0          3.0
# 16              NaN                 NaN  7800769.0        8.0          3.0
# 17              NaN                 NaN  7799188.0        8.0          3.0
# 18              NaN                 NaN  7799199.0        8.0          3.0
# 19              NaN                 NaN  7799329.0        8.0          3.0
# 20              NaN                 NaN  7799544.0        8.0          3.0
# 21              NaN                 NaN  7799760.0        8.0          3.0
# 22              NaN                 NaN  7799994.0        8.0          3.0
# 23              NaN                 NaN  7800641.0        8.0          3.0
# 24              NaN                 NaN  7799917.0        8.0          3.0
# 25              NaN                 NaN  7809647.0        8.0          3.0
# 26              NaN                 NaN  7824469.0        8.0          3.0
# 27              NaN                 NaN  7825918.0        8.0          3.0
# 28              NaN                 NaN  7825940.0        8.0          3.0
# 29              NaN                 NaN  7800910.0        8.0          3.0
# ...             ...                 ...        ...        ...          ...
# 2002            NaN                 NaN        NaN        NaN          NaN
# 2003            NaN                 NaN        NaN        NaN          NaN
# 2004            NaN                 NaN        NaN        NaN          NaN
# 2005            NaN                 NaN        NaN        NaN          NaN
# 2006            NaN                 NaN        NaN        NaN          NaN
# 2007            NaN                 NaN        NaN        NaN          NaN
# 2008            NaN                 NaN        NaN        NaN          NaN
# 2009            NaN                 NaN        NaN        NaN          NaN
# 2010            NaN                 NaN        NaN        NaN          NaN
# 2011            NaN                 NaN        NaN        NaN          NaN
# 2012            NaN                 NaN        NaN        NaN          NaN
# 2013            NaN                 NaN        NaN        NaN          NaN
# 2014            NaN                 NaN        NaN        NaN          NaN
# 2015            NaN                 NaN        NaN        NaN          NaN
# 2016            NaN                 NaN        NaN        NaN          NaN
# 2017            NaN                 NaN        NaN        NaN          NaN
# 2018            NaN                 NaN        NaN        NaN          NaN
# 2019            NaN                 NaN        NaN        NaN          NaN
# 2020            NaN                 NaN        NaN        NaN          NaN
# 2021            NaN                 NaN        NaN        NaN          NaN
# 2022            NaN                 NaN        NaN        NaN          NaN
# 2023            NaN                 NaN        NaN        NaN          NaN
# 2024            NaN                 NaN        NaN        NaN          NaN
# 2025            NaN                 NaN        NaN        NaN          NaN
# 2026            NaN                 NaN        NaN        NaN          NaN
# 2027            NaN                 NaN        NaN        NaN          NaN
# 2028            NaN                 NaN        NaN        NaN          NaN
# 2029            NaN                 NaN        NaN        NaN          NaN
# 2030            NaN                 NaN        NaN        NaN          NaN
# 2031            NaN                 NaN        NaN        NaN          NaN
#
#        shipment_id  length         orderno sentiment        category
# 0     2.022986e+09   138.0             NaN  Positive        Delivery
# 1     2.022943e+09    60.0             NaN  Positive       Warehouse
# 2     2.022973e+09   472.0             NaN  Negative        Category
# 3     2.022682e+09    43.0             NaN  Positive        Delivery
# 4     2.023155e+09    26.0             NaN  Positive        Delivery
# 5     2.023279e+09    26.0             NaN  Positive        Delivery
# 6     2.023176e+09    35.0             NaN  Positive        Category
# 7     2.023057e+09   169.0             NaN  Negative        Category
# 8     2.023181e+09    49.0             NaN  Positive        Delivery
# 9     2.022665e+09    52.0             NaN  Positive        Delivery
# 10    2.022918e+09    62.0             NaN  Positive        Delivery
# 11    2.022810e+09    89.0             NaN  Positive        Delivery
# 12    2.022882e+09    85.0             NaN  Positive        Delivery
# 13    2.023262e+09    33.0             NaN  Positive        Delivery
# 14    2.022867e+09    43.0             NaN  Positive        Delivery
# 15    2.023223e+09    43.0             NaN  Positive        Delivery
# 16    2.022874e+09   141.0             NaN  Positive        Delivery
# 17    2.023180e+09   137.0             NaN  Positive        Delivery
# 18    2.022769e+09    59.0             NaN  Positive        Category
# 19    1.595839e+09    92.0             NaN  Positive        Delivery
# 20    2.022914e+09    80.0             NaN  Negative        Category
# 21    2.023126e+09    53.0             NaN  Positive        Delivery
# 22    2.023164e+09    56.0             NaN  Positive        Delivery
# 23    2.022699e+09    56.0             NaN  Positive        Delivery
# 24    2.023257e+09    21.0             NaN  Positive        Delivery
# 25    2.022925e+09    75.0             NaN  Positive        Category
# 26    2.022527e+09    60.0             NaN  Positive        Delivery
# 27    2.022876e+09    92.0             NaN  Positive        Delivery
# 28    2.023200e+09    92.0             NaN  Positive        Delivery
# 29    2.022460e+09   107.0             NaN  Positive        Delivery
# ...            ...     ...             ...       ...             ...
# 2002           NaN     NaN       907888574  Positive        Category
# 2003           NaN     NaN       907888879  Positive        Delivery
# 2004           NaN     NaN        1.36E+12  Positive         General
# 2005           NaN     NaN     MLJC3374807  Positive        Category
# 2006           NaN     NaN     MLJP3809663  Negative        Category
# 2007           NaN     NaN     MLJP3620371  Negative       Warehouse
# 2008           NaN     NaN     MLJC3378009  Positive         General
# 2009           NaN     NaN     MLJC3424226  Positive        Delivery
# 2010           NaN     NaN     MLJP3748949  Positive        Delivery
# 2011           NaN     NaN     MLJP3768697  Negative              CC
# 2012           NaN     NaN     MLJP3775571  Positive        Category
# 2013           NaN     NaN        59790158  Negative         Finance
# 2014           NaN     NaN     MLJC3390055  Positive        Delivery
# 2015           NaN     NaN  JBNP0003894954  Positive        Delivery
# 2016           NaN     NaN     MLJP3754100  Negative              CE
# 2017           NaN     NaN     MLJP3736993  Negative       Warehouse
# 2018           NaN     NaN     MLJP3768717  Positive        Category
# 2019           NaN     NaN     MLJP3772879  Positive        Category
# 2020           NaN     NaN       907889079  Positive        Delivery
# 2021           NaN     NaN     MLJP3785771  Positive        Category
# 2022           NaN     NaN     MLJP3783086  Negative        Delivery
# 2023           NaN     NaN     MLJP3741357  Negative        Category
# 2024           NaN     NaN  JBNP0003898444  Positive        Category
# 2025           NaN     NaN        59737263  Negative       Warehouse
# 2026           NaN     NaN     MLJC3420696  Positive  Retail-Revenue
# 2027           NaN     NaN     MLJC3379722  Negative        Category
# 2028           NaN     NaN  JBNP0003896832  Positive        Category
# 2029           NaN     NaN     MLJP3773254  Negative        Category
# 2030           NaN     NaN        59551680  Positive        Category
# 2031           NaN     NaN     MLJC3369686  Positive         General
#
# [2032 rows x 15 columns]

# %%
Test.to_csv("Test_cat.csv")

# %% [markdown]
# # Logistic Regression for Subb-category

# %%
from sklearn.cross_validation import train_test_split

# remember that corpus_data_features_nd contains all of our original train and test data, so we need to exclude
# the unlabeled test entries
X_train, X_test, y_train, y_test  = train_test_split(
    corpus_data_features_nd[0:len(Train)], 
    Train.sub_category,
    train_size=0.85, 
    random_state=1234)

# %%
from sklearn.linear_model import LogisticRegression

log_model = LogisticRegression()
log_model = log_model.fit(X=X_train, y=y_train)

# %%
y_pred = log_model.predict(X_test)

# %%
y_pred
# Out:
# array(['null', 'Others', 'Delivery boy behaviour', ..., 'Size chart',
#        'null', 'Returns and exchange policy'], dtype=object)

# %%
from sklearn import metrics, cross_validation
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.636166253101737

# %%
# train classifier
log_model = LogisticRegression()
log_model = log_model.fit(X=corpus_data_features_nd[0:len(Train)], y=Train.sub_category)

# %%
test_pred = log_model.predict(corpus_data_features_nd[len(Train):])

# %%
test_pred.shape
# Out:
# (2032,)

# %%
Test["sub-category"]= test_pred

# %%
Test
# Out:
#       data_id  survey request id survey received date  \
# 0     2462639        135315888.0            09-Apr-18
# 1     2462642        135318061.0            09-Apr-18
# 2     2462646        135318991.0            09-Apr-18
# 3     2462648        135319199.0            09-Apr-18
# 4     2462652        135320109.0            09-Apr-18
# 5     2466538        137240739.0            13-Apr-18
# 6     2462665        135322815.0            09-Apr-18
# 7     2462668        135323451.0            09-Apr-18
# 8     2462670        135323713.0            09-Apr-18
# 9     2462676        135324910.0            09-Apr-18
# 10    2462680        135326709.0            09-Apr-18
# 11    2462684        135327122.0            09-Apr-18
# 12    2462686        135328640.0            09-Apr-18
# 13    2462688        135329650.0            09-Apr-18
# 14    2462690        135330082.0            09-Apr-18
# 15    2462694        135330863.0            09-Apr-18
# 16    2462697        135331780.0            09-Apr-18
# 17    2462703        135332678.0            09-Apr-18
# 18    2462706        135334915.0            09-Apr-18
# 19    2462709        135335228.0            09-Apr-18
# 20    2462720        135338352.0            09-Apr-18
# 21    2462728        135340079.0            09-Apr-18
# 22    2462735        135342893.0            09-Apr-18
# 23    2462737        135343514.0            09-Apr-18
# 24    2462742        135345463.0            09-Apr-18
# 25    2462745        135346099.0            09-Apr-18
# 26    2462747        135346725.0            09-Apr-18
# 27    2462754        135348266.0            09-Apr-18
# 28    2463475        135606900.0            09-Apr-18
# 29    2462759        135350874.0            09-Apr-18
# ...       ...                ...                  ...
# 2002  2462509                NaN           17/04/2018
# 2003  2462511                NaN           17/04/2018
# 2004  2462516                NaN           17/04/2018
# 2005  2462524                NaN           17/04/2018
# 2006  2462528                NaN           17/04/2018
# 2007  2462531                NaN           17/04/2018
# 2008  2462533                NaN           17/04/2018
# 2009  2462534                NaN           17/04/2018
# 2010  2462549                NaN           17/04/2018
# 2011  2462550                NaN           17/04/2018
# 2012  2462557                NaN           17/04/2018
# 2013  2462565                NaN           17/04/2018
# 2014  2462566                NaN           17/04/2018
# 2015  2462567                NaN           17/04/2018
# 2016  2462571                NaN           17/04/2018
# 2017  2462581                NaN           17/04/2018
# 2018  2462585                NaN           17/04/2018
# 2019  2462586                NaN           17/04/2018
# 2020  2462590                NaN           17/04/2018
# 2021  2462596                NaN           17/04/2018
# 2022  2462597                NaN           17/04/2018
# 2023  2462598                NaN           17/04/2018
# 2024  2462600                NaN           17/04/2018
# 2025  2462605                NaN           17/04/2018
# 2026  2462609                NaN           17/04/2018
# 2027  2462611                NaN           17/04/2018
# 2028  2462616                NaN           17/04/2018
# 2029  2462618                NaN           17/04/2018
# 2030  2462623                NaN           17/04/2018
# 2031  2462632                NaN           17/04/2018
#
#                                                feedback survey name  \
# 0     Delivery is on expected date and that what I l...           C
# 1     It's very good Packing condition some times.qu...           C
# 2     This was my first purchase with myantra and I ...           C
# 3           Product is nice and delivery man was awsome           C
# 4                            Delivery is good and fast.           C
# 5                            Delivery is good and fast.           C
# 6                   On time with nice product i love it           C
# 7     This item which received it's very poor qualit...           C
# 8     Delivery man is very polite and very fast service           C
# 9     Delivery executive was very polite and profess...           C
# 10    Awesome product.really appreciate the service ...           C
# 11    Delivery boy is good and delivery timing is al...           C
# 12    This boy is very gud and delivers on time..i m...           C
# 13                    The delivery boy was very polite.           C
# 14          Very polite and delivered it before time...           C
# 15          timely delivered by well mannered executive           C
# 16    Very smooth delivery.. very good experience al...           C
# 17    On time delievery...would like to appreciate t...           C
# 18    I love this product and very early delivery th...           C
# 19    A delivery guy was too good. On time delivery....           C
# 20    The quality and delivery was just the way I ex...           C
# 21    Delivery is always on time. Cloth material is ...           C
# 22    Fast delivery and very happy with the apparel....           C
# 23    Awesome stuff and a good delivery person farro...           C
# 24                                He is always on time.           C
# 25    Nice service given by you and it was timely gi...           C
# 26    The delivery was on time..n d delivery boy was...           C
# 27    Great courtesy. Nice communication and timely ...           C
# 28    Great courtesy. Nice communication and timely ...           C
# 29    Osm delivery The product is really good I luv ...           C
# ...                                                 ...         ...
# 2002  Everything is perfect. Quality of product, fit...           D
# 2003  All is excellent .... product as well as delivery           D
# 2004                                             nice n           D
# 2005  The dresses I ordered were amazing. Such a goo...           D
# 2006  As seen the product , i don't think its genuin...           D
# 2007  the delivered size was wrong and could not exc...           D
# 2008                                   Extremely good!!           D
# 2009  Product is really good. And always delivered o...           D
# 2010  The delivery was good. And the product was als...           D
# 2011  Wrong item delivered. Customer care suggests c...           D
# 2012  Awesome!!! Liked using the app with ease & ver...           D
# 2013  according to you refund is initiated and refun...           R
# 2014  What a discount on original Nike product , ama...           D
# 2015            Awesome product & fast delivery service           D
# 2016  In the website its written cotton pantties whe...           D
# 2017  It is mentioned on app that this bra is padded...           D
# 2018  My daughter was anxiously awaiting the product...           D
# 2019  I like the Jabong app search experience. It is...           D
# 2020  Discount..delivery before time...cash on deliv...           D
# 2021  Excellent original quality.... Loads of variet...           D
# 2022  I placed order for 2 numbers of the same item ...           D
# 2023  The product looks exactly like it's in the ima...           D
# 2024  It’s a very nice skirt and I got it six days b...           D
# 2025  I ordered 34 size belt and delivery was 38 siz...           R
# 2026       Fast delivery.good product/price.keep it up.           D
# 2027  Recieved a defective product..it is used...I a...           D
# 2028                  Very good quality for the price.            D
# 2029  Totally dissatisfied. Bad quality, XS size is ...           D
# 2030  Very nice products and ease of exchange of the...           R
# 2031                                   Fully satisfied            D
#
#       delivery type survey created date   id(r id)  option_id  question_id  \
# 0               NaN                 NaN  7816906.0        8.0          3.0
# 1               NaN                 NaN  7797966.0        8.0          3.0
# 2               NaN                 NaN  7798168.0        8.0          3.0
# 3               NaN                 NaN  7798604.0        8.0          3.0
# 4               NaN                 NaN  7798150.0        8.0          3.0
# 5               NaN                 NaN  7934069.0        8.0          3.0
# 6               NaN                 NaN  7798444.0        8.0          3.0
# 7               NaN                 NaN  7823381.0        8.0          3.0
# 8               NaN                 NaN  7813418.0        8.0          3.0
# 9               NaN                 NaN  7798573.0        8.0          3.0
# 10              NaN                 NaN  7799970.0        8.0          3.0
# 11              NaN                 NaN  7806814.0        8.0          3.0
# 12              NaN                 NaN  7799690.0        8.0          3.0
# 13              NaN                 NaN  7798972.0        8.0          3.0
# 14              NaN                 NaN  7799014.0        8.0          3.0
# 15              NaN                 NaN  7799586.0        8.0          3.0
# 16              NaN                 NaN  7800769.0        8.0          3.0
# 17              NaN                 NaN  7799188.0        8.0          3.0
# 18              NaN                 NaN  7799199.0        8.0          3.0
# 19              NaN                 NaN  7799329.0        8.0          3.0
# 20              NaN                 NaN  7799544.0        8.0          3.0
# 21              NaN                 NaN  7799760.0        8.0          3.0
# 22              NaN                 NaN  7799994.0        8.0          3.0
# 23              NaN                 NaN  7800641.0        8.0          3.0
# 24              NaN                 NaN  7799917.0        8.0          3.0
# 25              NaN                 NaN  7809647.0        8.0          3.0
# 26              NaN                 NaN  7824469.0        8.0          3.0
# 27              NaN                 NaN  7825918.0        8.0          3.0
# 28              NaN                 NaN  7825940.0        8.0          3.0
# 29              NaN                 NaN  7800910.0        8.0          3.0
# ...             ...                 ...        ...        ...          ...
# 2002            NaN                 NaN        NaN        NaN          NaN
# 2003            NaN                 NaN        NaN        NaN          NaN
# 2004            NaN                 NaN        NaN        NaN          NaN
# 2005            NaN                 NaN        NaN        NaN          NaN
# 2006            NaN                 NaN        NaN        NaN          NaN
# 2007            NaN                 NaN        NaN        NaN          NaN
# 2008            NaN                 NaN        NaN        NaN          NaN
# 2009            NaN                 NaN        NaN        NaN          NaN
# 2010            NaN                 NaN        NaN        NaN          NaN
# 2011            NaN                 NaN        NaN        NaN          NaN
# 2012            NaN                 NaN        NaN        NaN          NaN
# 2013            NaN                 NaN        NaN        NaN          NaN
# 2014            NaN                 NaN        NaN        NaN          NaN
# 2015            NaN                 NaN        NaN        NaN          NaN
# 2016            NaN                 NaN        NaN        NaN          NaN
# 2017            NaN                 NaN        NaN        NaN          NaN
# 2018            NaN                 NaN        NaN        NaN          NaN
# 2019            NaN                 NaN        NaN        NaN          NaN
# 2020            NaN                 NaN        NaN        NaN          NaN
# 2021            NaN                 NaN        NaN        NaN          NaN
# 2022            NaN                 NaN        NaN        NaN          NaN
# 2023            NaN                 NaN        NaN        NaN          NaN
# 2024            NaN                 NaN        NaN        NaN          NaN
# 2025            NaN                 NaN        NaN        NaN          NaN
# 2026            NaN                 NaN        NaN        NaN          NaN
# 2027            NaN                 NaN        NaN        NaN          NaN
# 2028            NaN                 NaN        NaN        NaN          NaN
# 2029            NaN                 NaN        NaN        NaN          NaN
# 2030            NaN                 NaN        NaN        NaN          NaN
# 2031            NaN                 NaN        NaN        NaN          NaN
#
#        shipment_id  length         orderno sentiment        category  \
# 0     2.022986e+09   138.0             NaN  Positive        Delivery
# 1     2.022943e+09    60.0             NaN  Positive       Warehouse
# 2     2.022973e+09   472.0             NaN  Negative        Category
# 3     2.022682e+09    43.0             NaN  Positive        Delivery
# 4     2.023155e+09    26.0             NaN  Positive        Delivery
# 5     2.023279e+09    26.0             NaN  Positive        Delivery
# 6     2.023176e+09    35.0             NaN  Positive        Category
# 7     2.023057e+09   169.0             NaN  Negative        Category
# 8     2.023181e+09    49.0             NaN  Positive        Delivery
# 9     2.022665e+09    52.0             NaN  Positive        Delivery
# 10    2.022918e+09    62.0             NaN  Positive        Delivery
# 11    2.022810e+09    89.0             NaN  Positive        Delivery
# 12    2.022882e+09    85.0             NaN  Positive        Delivery
# 13    2.023262e+09    33.0             NaN  Positive        Delivery
# 14    2.022867e+09    43.0             NaN  Positive        Delivery
# 15    2.023223e+09    43.0             NaN  Positive        Delivery
# 16    2.022874e+09   141.0             NaN  Positive        Delivery
# 17    2.023180e+09   137.0             NaN  Positive        Delivery
# 18    2.022769e+09    59.0             NaN  Positive        Category
# 19    1.595839e+09    92.0             NaN  Positive        Delivery
# 20    2.022914e+09    80.0             NaN  Negative        Category
# 21    2.023126e+09    53.0             NaN  Positive        Delivery
# 22    2.023164e+09    56.0             NaN  Positive        Delivery
# 23    2.022699e+09    56.0             NaN  Positive        Delivery
# 24    2.023257e+09    21.0             NaN  Positive        Delivery
# 25    2.022925e+09    75.0             NaN  Positive        Category
# 26    2.022527e+09    60.0             NaN  Positive        Delivery
# 27    2.022876e+09    92.0             NaN  Positive        Delivery
# 28    2.023200e+09    92.0             NaN  Positive        Delivery
# 29    2.022460e+09   107.0             NaN  Positive        Delivery
# ...            ...     ...             ...       ...             ...
# 2002           NaN     NaN       907888574  Positive        Category
# 2003           NaN     NaN       907888879  Positive        Delivery
# 2004           NaN     NaN        1.36E+12  Positive         General
# 2005           NaN     NaN     MLJC3374807  Positive        Category
# 2006           NaN     NaN     MLJP3809663  Negative        Category
# 2007           NaN     NaN     MLJP3620371  Negative       Warehouse
# 2008           NaN     NaN     MLJC3378009  Positive         General
# 2009           NaN     NaN     MLJC3424226  Positive        Delivery
# 2010           NaN     NaN     MLJP3748949  Positive        Delivery
# 2011           NaN     NaN     MLJP3768697  Negative              CC
# 2012           NaN     NaN     MLJP3775571  Positive        Category
# 2013           NaN     NaN        59790158  Negative         Finance
# 2014           NaN     NaN     MLJC3390055  Positive        Delivery
# 2015           NaN     NaN  JBNP0003894954  Positive        Delivery
# 2016           NaN     NaN     MLJP3754100  Negative              CE
# 2017           NaN     NaN     MLJP3736993  Negative       Warehouse
# 2018           NaN     NaN     MLJP3768717  Positive        Category
# 2019           NaN     NaN     MLJP3772879  Positive        Category
# 2020           NaN     NaN       907889079  Positive        Delivery
# 2021           NaN     NaN     MLJP3785771  Positive        Category
# 2022           NaN     NaN     MLJP3783086  Negative        Delivery
# 2023           NaN     NaN     MLJP3741357  Negative        Category
# 2024           NaN     NaN  JBNP0003898444  Positive        Category
# 2025           NaN     NaN        59737263  Negative       Warehouse
# 2026           NaN     NaN     MLJC3420696  Positive  Retail-Revenue
# 2027           NaN     NaN     MLJC3379722  Negative        Category
# 2028           NaN     NaN  JBNP0003896832  Positive        Category
# 2029           NaN     NaN     MLJP3773254  Negative        Category
# 2030           NaN     NaN        59551680  Positive        Category
# 2031           NaN     NaN     MLJC3369686  Positive         General
#
#                              sub-category
# 0                          Delivery speed
# 1                    Quality of packaging
# 2                    Quality of packaging
# 3                         Product quality
# 4                          Delivery speed
# 5                          Delivery speed
# 6                         Product quality
# 7                  Received wrong product
# 8                          Delivery speed
# 9                  Delivery boy behaviour
# 10                 Delivery boy behaviour
# 11                 Delivery boy behaviour
# 12                 Delivery boy behaviour
# 13                 Delivery boy behaviour
# 14                 Delivery boy behaviour
# 15                 Delivery boy behaviour
# 16                         Delivery speed
# 17                 Delivery boy behaviour
# 18                        Product quality
# 19                 Delivery boy behaviour
# 20                        Product quality
# 21                         Delivery speed
# 22                         Delivery speed
# 23                 Delivery boy behaviour
# 24                                   null
# 25                        Product quality
# 26                 Delivery boy behaviour
# 27                         Delivery speed
# 28                         Delivery speed
# 29                         Delivery speed
# ...                                   ...
# 2002                      Product quality
# 2003                       Delivery speed
# 2004                                 null
# 2005                   Fitting of product
# 2006                      Product quality
# 2007               Received wrong product
# 2008                                 null
# 2009                       Delivery speed
# 2010                      Product quality
# 2011  Agent behaviour/Quality of response
# 2012                      Product quality
# 2013                          Refund time
# 2014                       Delivery speed
# 2015                       Delivery speed
# 2016          Returns and exchange policy
# 2017           Received defective product
# 2018                      Product quality
# 2019                      Product quality
# 2020                       Delivery speed
# 2021                       Delivery speed
# 2022                       Delivery speed
# 2023                      Product quality
# 2024                      Product quality
# 2025                           Size chart
# 2026                       Delivery speed
# 2027                      Product quality
# 2028                      Product quality
# 2029                      Product quality
# 2030                      Product quality
# 2031                                 null
#
# [2032 rows x 16 columns]

# %%
Test.to_csv("Test_cat_subcat.csv")

# %%
Test["sub-category"]=Test["sub-category"].replace("null", " ")

# %%
Test.to_csv("Test_cat_subcat_new.csv")

# %%
Merged_version1= pd.read_csv("/Users/kamakshibansal/Merged_version1.csv")
Test_cat_subcat_new= pd.read_csv("/Users/kamakshibansal/Test_cat_subcat_new.csv")

# %%
Final_version=pd.concat([Merged_version1,Test_cat_subcat_new])
Final_version.shape
# Out:
# (25628, 16)

# %%
Final_version.to_csv("Final_version.csv")
